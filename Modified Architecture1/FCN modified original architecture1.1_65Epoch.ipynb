# %% [markdown]
# # Fully convolutional network for semantic segmentation
#
# Semantic segmentation belongs to scene understanding field, and it is the task of assigning meaning to a part of an object. This can be done at the pixel level where we assign each pixel to a target class.
#
# The goal is to input an image into a neural network and output a category for every pixel. We'll have a set of categories, much like in a classification task. But instead of assigning a single class to an image we want to assign a class to every pixel in that image.
#
# FCNs achieves state-of-art in tasks like semantic segmentation, by taking advantage of three special techniques:
# - Replace fully connected layers with one by one convolutional layer.
# - Up-sampling through the use of transposed convolutional layers.
# - Adding skip connections. (This allows the network to use information from multiple resolution scales)
#
# This network takes in an image that has true labels attached to each pixel and then it outputs a tensor with dimension:``` classes x height x width. ```
#
# **FCN limitations**
#
# - It is very expensive to label every pixel.
# - It is computationally expensive to maintain spatial information in each convolutional layer.

# %% [markdown]
# ## Set up Google Colab

# %% [markdown]
# ### Connect with Google drive

# %%
from google.colab import files
train = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Go to the project directory

# %%
# %cd "/content/drive/My Drive/"
# %ls
# Out:
# /content/drive/My Drive
#  CamVid/
# 'Case Study'/
# 'Colab Notebooks'/
# 'Data Science'/
#  Dissertation/
#  fcn-model-50Epoch.pth
#  fcn-model-55Epoch.pth
#  fcn-model-meaniuo-55Epoch.pth
#  fcn-model-meaniuo.pth
#  fcn-model-modified_architecture1.1.pth
#  fcn-model-modified_architecture1.2.pth
#  fcn-model-modified_architecture1.3.pth
#  fcn-model-modified_architecture1.pth
#  fcn-model-modified_architecture2.pth
#  fcn-model-original1.1.pth
#  fcn-model-original-lasttraining.pth
#  fcn-model.pth
#  fcn-modified-model1.pth
#  fcn-modified-model2.pth
#  Glasgow.rar
# 'Hands-On Machine Learning with Scikit-Learn and TensorFlow_ Concepts, Tools, and Techniques to Build Intelligent Systems-Aurélien Géron - (2017).pdf'
#  Handycam/
# 'How to get started with Drive.pdf'
# 'Introduction to Machine Learning with Python  A Guide for Data Scientists-Andreas C. Muller, Sarah Guido - (2016).pdf'
#  Law/
#  MATLAB/
# 'My Schedule.gsheet'
#  Photo/
#  Presentation/
#  Proposal/
# 'Pytorch Visualization'/
#  train_path2.csv
#  Transcript.pdf
#  trn_loss_modified_architecture1.1.csv
#  trn_loss_modified_architecture1.2.csv
#  trn_loss_modified_architecture1.2.npy
#  trn_loss_modified_architecture1.3.csv
#  trn_loss_modified_architecture1.3.npy
#  trn_loss_original.csv
#  trn_loss_original.npy
#  val_loss_modified_architecture1.1.csv
#  val_loss_modified_architecture1.2.csv
#  val_loss_modified_architecture1.2.npy
#  val_loss_modified_architecture1.3.csv
#  val_loss_modified_architecture1.3.npy
#  val_loss_original.csv
#  val_loss_original.npy
#  val_path2.csv
#  Video/

# %% [markdown]
# ### Install packages

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline 


import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
import pandas as pd
import scipy.misc
import imageio
import random

import torch
import torch.nn as nn
import torch.functional as F
from torch import optim

import torchvision
from torchvision import models, datasets, transforms, utils
from torchvision.models.vgg import VGG
from torch.utils.data import Dataset

import torch.utils.data as data
import glob
import cv2
import os
import io
from PIL import Image

from statistics import mean

#import albumentations as A
#from pytorch_toolbelt.utils import fs

# %% [markdown]
# ## Data
#
# [CamVid](http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamVid/) is a motion-based segmentation and recognition [dataset](https://github.com/mostafaizz/camvid) that contains 701 images, 701 labeled images, and a file with a list of classes with their correspondence in RGB code.
#
# **NOTE:**
# I pre-processed the labeled images by changing their RGB values for class ids. Instead of doing it directly on the CamVid class, do it separately and save the result as a .npy file to improve the performance ([Here](https://towardsdatascience.com/why-you-should-start-using-npy-file-more-often-df2a13cc0161) is an interesting article about that). In this way you cannot use PyTorch transforms on a label image, since PIL will change the class id for color values. Also, CamVid images are very similar, so adding augmentation like RandomCrop or RandomHorizontalFlip helps the network.

# %% [markdown]
# ### Load data

# %%
class CamVid(Dataset):
  
  def __init__(self, csv_file, phase):
    self.phase = phase
    self.data = pd.read_csv(csv_file)
    
    if phase == 'train':
        self.input_shape = (576, 768)
    elif phase == 'valid':
        self.input_shape = (704, 960)
  
  def __getitem__(self, index):
    image, label = self.data.iloc[index, 1], self.data.iloc[index, 2]
    image = imageio.imread(image,pilmode="RGB")
    label = np.load(label)
        
    if self.phase == "train":
         # RandomCrop
        h, w, _ = image.shape
        new_h, new_w = self.input_shape
        top = random.randint(0, h - new_h)
        left = random.randint(0, w - new_w)
        image = image[top:top + new_h, left:left + new_w]
        label = label[top:top + new_h, left:left + new_w]
      
      # RandomHorizontalFlip
    if random.random() < 0.5:
        image = np.fliplr(image)
        label = np.fliplr(label)
        
    if self.phase == "valid":
      # "Resize"
        new_h, new_w = self.input_shape
        image = image[0:new_h, 0:new_w]
        label = label[0:new_h, 0:new_w]
          
    # Normalization 
    mean=[0.485, 0.456, 0.460]
    std =[0.229, 0.224, 0.225]
    
    image = np.transpose(image, (2, 0, 1)) / 255.
    image[0] = (image[0] - mean[0]) / std[0]
    image[1] = (image[1] - mean[1]) / std[1]
    image[2] = (image[2] - mean[2]) / std[2]
    
    # ToTensor 
    image = torch.from_numpy(image.copy()).float()
    label = torch.from_numpy(label.copy()).long()
  
    # One-hot encoding 
    h, w = label.size()
    target = torch.zeros(32, h, w)
    for c in range(32):
        target[c][label == c] = 1
        
    return {'x': image, 'y':target, 'l':label} 

  def __len__(self):
    return len(self.data)

# %%
train_data = CamVid("/content/drive/My Drive/train_path2.csv", phase="train")
valid_data = CamVid("/content/drive/My Drive/val_path2.csv", phase="valid")

trainloader = torch.utils.data.DataLoader(train_data, batch_size=5, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=1)

# %% [markdown]
# ### Visualize a single batch

# %%
def show_batch(batch):
  mean=[0.485, 0.456, 0.460]
  std =[0.229, 0.224, 0.225]
  
  img_batch = batch['x']
 
  # Desnormalize 
  img_batch[:,0,...].mul_(std[0]).add_(mean[0])
  img_batch[:,1,...].mul_(std[1]).add_(mean[1])
  img_batch[:,2,...].mul_(std[2]).add_(mean[2])
  
  img_batch = np.clip(img_batch, 0, 1)
  grid = utils.make_grid(img_batch)
  
  plt.rcParams['figure.figsize'] = [20, 7.0]
  plt.figure()
  plt.title('Batch from training data')
  plt.imshow(grid.numpy().transpose((1, 2, 0)))
  plt.axis('off')
  plt.ioff()
  plt.show
    
batch = next(iter(trainloader))
print(batch['x'].size(), batch['y'].size(), batch['l'].size())
show_batch(batch)
# Out:
# torch.Size([5, 3, 576, 768]) torch.Size([5, 32, 576, 768]) torch.Size([5, 576, 768])

# %% [markdown]
# ## Model

# %% [markdown]
# ### Encoder
#
# Its goal is to extract features from the image. In this case, I used the pretrained VGG16 model and removed the classifier (the fully connected layer at the end).  Doing so casts it into a fully convolutional network that outputs classification maps (heatmaps). Also saved the score of three different pooling layers that the decoder will use to perform skip connections.

# %%
class VGG16(VGG):
  
  def __init__(self, cfg, ranges, pretrained=True, model='vgg16', requires_grad=True, remove_fc=True, show_params=False):
    super().__init__(self.make_layers(cfg[model]))
    
    self.ranges = ranges[model]
        
    if pretrained:
      exec("self.load_state_dict(models.%s(pretrained=True).state_dict())" % model) #Loading all weights 
    if not requires_grad:
      for parameter in super().parameters(): # False if you want to freeze the encoder and avoid to train it.
        parameter.requires_grad = False
    if remove_fc: 
      del self.classifier
      del self.avgpool
    if show_params:  # Display the params to see the dimensionallity
      for name, parameter in self.named_parameters():
        print(name, parameter.size())
        
  def forward(self, x):
    output = {}
    
    # Get the output of each maxpooling layer (There are 5 in VGG) to create skip connections.
    for idx in range(len(self.ranges)): #range is below the decoder: ranges = {'vgg16': ((0, 5), (5, 10), (10, 17), (17, 24), (24, 31))}
      for layer in range(self.ranges[idx][0], self.ranges[idx][1]):
        x = self.features[layer](x)
      output["pool%d"%(idx+1)] = x #naming the layer:pool(index+1)
    
    return output 
  
  def make_layers(self, cfg, batch_norm=False):
    layers = []
    in_channels = 3
    for v in cfg:   #cfg = {'vgg16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],}
      if v == 'M':
        layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
      else:
        conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
        if batch_norm:
          layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
        else:
          layers += [conv2d, nn.ReLU(inplace=True)]
        in_channels = v
    return nn.Sequential(*layers)

# %%
ranges = {'vgg16': ((0, 5), (5, 10), (10, 17), (17, 24), (24, 31))} #up to each maxpooling layer
cfg = {'vgg16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],}

# %%
VGG16(cfg,ranges)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# VGG16(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ### Decoder
#
# It up-scales the output of the encoder such that it's the same size as the original image.
#
# - **Convolutional score layer** - This will result in the output of a 4D tensor instead of a flattened 2D tensor, so spatial information will be preserved. Effectively, this turns convolutions into a matrix multiplication with spatial information. The number of kernels is equivalent to the number of outputs.
#
# - **Transposed convolutions** - Is essentially a reverse convolution in which the forward and the backward passes are swapped. They help in upsampling the previous layer to a higher resolution or dimension.
#
# - **Skip connections** - They allow the network to use information from multiple resolutions, and as a result, the network is able to make more precise segmentation decisions.

# %%
class FCN8s(nn.Module):
  
  def __init__(self, pretrained_model, n_classes):
    super().__init__()
    
    self.n_classes = n_classes
    self.pretrained_model = pretrained_model
    #Convolutional layers
    self.relu = nn.ReLU(inplace=True)

    #Extra layers
    self.conv1= nn.Conv2d(512,640,kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    self.conv2= nn.Conv2d(640,640,kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    self.conv3=nn.Conv2d(640,640,kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    self.pool6=nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)

    self.conv4 = nn.Conv2d(in_channels=640, out_channels=4096, kernel_size=7, padding=3)
    self.dropout1 = nn.Dropout(0.85)

    self.conv5 = nn.Conv2d(in_channels=4096, out_channels=4096, kernel_size=1)
    self.dropout2 = nn.Dropout(0.85)

    self.conv6 = nn.Conv2d(in_channels=4096, out_channels=n_classes, kernel_size=1)
    
    # Transposed convolutions (to upsampling previous layers)
    self.deconv1 = nn.ConvTranspose2d(in_channels=n_classes, out_channels=512, kernel_size=4, stride=2, padding=1)
    self.bn1 = nn.BatchNorm2d(512)
    self.deconv2 = nn.ConvTranspose2d(in_channels=512, out_channels=512, kernel_size=4, stride=2, padding=1)
    self.bn2 = nn.BatchNorm2d(512)
    self.deconv3 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=4, stride=2, padding=1)
    self.bn3 = nn.BatchNorm2d(256)
    self.deconv4 = nn.ConvTranspose2d(in_channels=256, out_channels=n_classes, kernel_size=16, stride=8, padding=4)
    self.bn4 = nn.BatchNorm2d(n_classes)
    # Convolutional score layer (replace the FC layers)
    self.score = nn.Conv2d(n_classes, n_classes, 1)
  
  def forward(self, x):
    x = self.pretrained_model(x)
    
    # Skip connections (connect the output of one layer to a non-adjacent layer)
    pool_5 = x['pool5']
    pool_4 = x['pool4']
    pool_3 = x['pool3']
    
    x = self.relu(self.conv1(pool_5))
    x = self.relu(self.conv2(x))
    x = self.relu(self.conv3(x))
    pool_6 =self.pool6(x)
    
    x = self.dropout1(self.relu(self.conv4(pool_6)))
    x = self.dropout2(self.relu(self.conv5(x)))
    x = self.relu(self.conv6(x))

    x = self.relu(self.deconv1(x))
    x = self.bn1(x + pool_5)
    x = self.relu(self.deconv2(x))
    x = self.bn2(x + pool_4)
    x = self.relu(self.deconv3(x))
    x = self.bn3(x+pool_3)
    x = self.bn4(self.relu(self.deconv4(x)))
    x = self.score(x)
    
    return x

# %% [markdown]
# ###  Test output sizes

# %%
batch_size, n_classes, h, w = 4, 20, 576, 768

encoder = VGG16(cfg, ranges, requires_grad=True)
decoder = FCN8s(encoder, n_classes)

enc_input = torch.randn(batch_size, 3, 160, 160)
dec_input = torch.randn(batch_size, 3, h, w)

enc_output = encoder(enc_input)
dec_output = decoder(dec_input)

assert enc_output['pool5'].size() == torch.Size([batch_size, 512, 5, 5])
assert dec_output.size() == torch.Size([batch_size, n_classes, h, w])
print("Correct output sizes")
# Out:
# Correct output sizes

# %% [markdown]
# ## Train model

# %% [markdown]
# ### Test if the model works using a single batch

# %%
fcn = FCN8s(VGG16(cfg,ranges), n_classes)
fcn
# Out:
# FCN8s(
#   (pretrained_model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (relu): ReLU(inplace=True)
#   (conv1): Conv2d(512, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(640, 4096, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (dropout1): Dropout(p=0.85, inplace=False)
#   (conv5): Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1))
#   (dropout2): Dropout(p=0.85, inplace=False)
#   (conv6): Conv2d(4096, 20, kernel_size=(1, 1), stride=(1, 1))
#   (deconv1): ConvTranspose2d(20, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv4): ConvTranspose2d(256, 20, kernel_size=(16, 16), stride=(8, 8), padding=(4, 4))
#   (bn4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (score): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
#fcn.pretrained_model.features[0]=nn.Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %%
fcn = FCN8s(VGG16(cfg,ranges), n_classes)

criterion = nn.BCELoss()
optimizer = optim.SGD(fcn.parameters(), lr=0.01, momentum=0.9)

x = torch.randn(batch_size, 3, h, w)
y = torch.randn(batch_size, n_classes, h, w)
y = torch.tensor(y, requires_grad=False)

for i in range(3):
  optimizer.zero_grad()
  output = fcn(x)
  output = torch.sigmoid(output)
  loss = criterion(output, y)
  loss.backward()
  print("i: {}, loss: {:.5f}".format(i, loss.item()))
  optimizer.step()

# %% [markdown]
# ### Set training parameters

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# Define model
n_classes = 32
model = FCN8s(VGG16(cfg, ranges), n_classes)

#state_dict = torch.load("/content/drive/My Drive/fcn-model.pth")
#model.load_state_dict(state_dict)

model.to(device)

# Define training parameters
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.RMSprop(model.parameters(), lr=0.0001, momentum=0, weight_decay=1e-5)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.5)
epochs = 65
print_every = 20

# Define scores
IoU_scores = np.zeros((epochs, n_classes))
pixel_scores = np.zeros(epochs)

# %% [markdown]
# ### Check accuracy before training

# %%
def iou(y_hat, y):
  ious = []
  for c in range(n_classes):
    pred_inds = y_hat == c
    target_inds = y == c
    intersection = pred_inds[target_inds].sum() # the intersection based of false or true scale which if pred=true and inds=false then the outcome would be empty and summing up elements to get the number of intersction points (True)
    union = pred_inds.sum() + target_inds.sum() - intersection
    if union == 0:
      ious.append(float('nan')) # If there is no ground truth, do not include in evaluation
    else:
      ious.append(float(intersection) / float(max(union, 1)))
  return ious

def pixel_accuracy(y_hat, y):
  correct = (y_hat == y).sum()
  total = (y == y).sum()
  return correct/total


def validation(model, validloader, criterion):
  total_ious = []
  pixel_accs = []
  for i, batch in enumerate(validloader):
    inputs = batch['x'].to(device)
    output = model(inputs)
    output = output.data.cpu().numpy()
        
    N, _, h, w = output.shape 
    pred = output.transpose(0, 2, 3, 1).reshape(-1, n_classes).argmax(axis=1).reshape(N, h, w) #transposing 32 class at the end and reshape it to collect all data in 32 classes then taking maximum value of each class
    target = batch['l'].cpu().numpy().reshape(N, h, w)
    
    for y_hat, y in zip(pred, target):
      total_ious.append(iou(y_hat, y))
      pixel_accs.append(pixel_accuracy(y_hat, y))
  
  # Pixel accuracy
  pixel_acc = np.array(pixel_accs).mean()
  
  # Mean IoU
  total_ious = np.array(total_ious).T
  mean_iou = np.nanmean(np.nanmean(total_ious, axis=1))
  
  return pixel_acc, mean_iou

# %%
model.eval()
with torch.no_grad():
  pixel_acc, mean_iou = validation(model, validloader, criterion)

print("Pixel accuracy: ", pixel_acc, " Mean IoU: ", mean_iou)
# Out:
# Pixel accuracy:  0.029077918149295987  Mean IoU:  0.005406922520444359

# %% [markdown]
# ### Train

# %%
train_losses=[]
train_losses_epoch=[]
valid_losses=[]
valid_losses_epoch=[]
meaniou_epoch=[]
for epoch in range(epochs):
  for i, batch in enumerate(trainloader):
    inputs_trn, labels_trn = batch['x'].to(device), batch['y'].to(device)
    
    model.train()
    optimizer.zero_grad()
    
    trn_outputs = model.forward(inputs_trn)
    trn_loss = criterion(trn_outputs, labels_trn)
    train_losses.append(trn_loss.item())
    trn_loss.backward()
    optimizer.step()
    if i % print_every == 0:
      print("Epoch: {}/{}.. ".format(epoch+1, epochs),
            "Training loss: {:.5f}.. ".format(trn_loss.item()))
  
  train_losses_epoch.append(mean(train_losses))
  train_losses=[]   
  
  model.eval()
  with torch.no_grad():
     paccuracy, meaniou = validation(model, validloader, criterion)
     for i, batch in enumerate(validloader):
       inputs_val, labels_val = batch['x'].to(device), batch['y'].to(device)
       val_outputs = model.forward(inputs_val)
       val_loss = criterion(val_outputs, labels_val)
       valid_losses.append(val_loss.item())
       
  valid_losses_epoch.append(mean(valid_losses))
  meaniou_epoch.append(meaniou)    
  print("Epoch: {}/{}.. ".format(epoch+1, epochs),
              "Validation loss: {:.5f}.. ".format(mean(valid_losses)),
              "Pixel accuracy.. {:.5f}".format(paccuracy),
              "Mean IU.. {:.5f}".format(meaniou))
  valid_losses=[] 


#Saving parameters
torch.save(model.state_dict(), "/content/drive/My Drive/fcn-model-modified_architecture1.1_65epoch.pth")
pd.DataFrame(train_losses_epoch).to_csv("/content/drive/My Drive/trn_loss_modified_architecture1.1_65epoch.csv",index=False)
pd.DataFrame(valid_losses_epoch).to_csv("/content/drive/My Drive/val_loss_modified_architecture1.1_65epoch.csv",index=False)
pd.DataFrame(meaniou_epoch).to_csv("/content/drive/My Drive/meaniou_modified_architecture1.1_65epoch.csv",index=False)
# Out:
# Epoch: 1/65..  Training loss: 0.71305..
# Epoch: 1/65..  Training loss: 0.65589..
# Epoch: 1/65..  Training loss: 0.64309..
# Epoch: 1/65..  Training loss: 0.64117..
# Epoch: 1/65..  Validation loss: 0.63547..  Pixel accuracy.. 0.79044 Mean IU.. 0.12024
# Epoch: 2/65..  Training loss: 0.63237..
# Epoch: 2/65..  Training loss: 0.62872..
# Epoch: 2/65..  Training loss: 0.62492..
# Epoch: 2/65..  Training loss: 0.62275..
# Epoch: 2/65..  Validation loss: 0.61414..  Pixel accuracy.. 0.79030 Mean IU.. 0.12093
# Epoch: 3/65..  Training loss: 0.62482..
# Epoch: 3/65..  Training loss: 0.61563..
# Epoch: 3/65..  Training loss: 0.61318..
# Epoch: 3/65..  Training loss: 0.60933..
# Epoch: 3/65..  Validation loss: 0.60579..  Pixel accuracy.. 0.82272 Mean IU.. 0.14110
# Epoch: 4/65..  Training loss: 0.60532..
# Epoch: 4/65..  Training loss: 0.60067..
# Epoch: 4/65..  Training loss: 0.59800..
# Epoch: 4/65..  Training loss: 0.59218..
# Epoch: 4/65..  Validation loss: 0.58923..  Pixel accuracy.. 0.82030 Mean IU.. 0.14781
# Epoch: 5/65..  Training loss: 0.59229..
# Epoch: 5/65..  Training loss: 0.58640..
# Epoch: 5/65..  Training loss: 0.58140..
# Epoch: 5/65..  Training loss: 0.58671..
# Epoch: 5/65..  Validation loss: 0.57163..  Pixel accuracy.. 0.83640 Mean IU.. 0.16472
# Epoch: 6/65..  Training loss: 0.57378..
# Epoch: 6/65..  Training loss: 0.57098..
# Epoch: 6/65..  Training loss: 0.56588..
# Epoch: 6/65..  Training loss: 0.56567..
# Epoch: 6/65..  Validation loss: 0.55810..  Pixel accuracy.. 0.83617 Mean IU.. 0.17114
# Epoch: 7/65..  Training loss: 0.55993..
# Epoch: 7/65..  Training loss: 0.55743..
# Epoch: 7/65..  Training loss: 0.55055..
# Epoch: 7/65..  Training loss: 0.54195..
# Epoch: 7/65..  Validation loss: 0.53774..  Pixel accuracy.. 0.85249 Mean IU.. 0.16471
# Epoch: 8/65..  Training loss: 0.54479..
# Epoch: 8/65..  Training loss: 0.54006..
# Epoch: 8/65..  Training loss: 0.52852..
# Epoch: 8/65..  Training loss: 0.53016..
# Epoch: 8/65..  Validation loss: 0.51385..  Pixel accuracy.. 0.85765 Mean IU.. 0.18729
# Epoch: 9/65..  Training loss: 0.52583..
# Epoch: 9/65..  Training loss: 0.51300..
# Epoch: 9/65..  Training loss: 0.51419..
# Epoch: 9/65..  Training loss: 0.50880..
# Epoch: 9/65..  Validation loss: 0.50009..  Pixel accuracy.. 0.85357 Mean IU.. 0.18055
# Epoch: 10/65..  Training loss: 0.50440..
# Epoch: 10/65..  Training loss: 0.50221..
# Epoch: 10/65..  Training loss: 0.49328..
# Epoch: 10/65..  Training loss: 0.49118..
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice
# Epoch: 10/65..  Validation loss: 0.48037..  Pixel accuracy.. 0.85538 Mean IU.. 0.19685
# Epoch: 11/65..  Training loss: 0.48340..
# Epoch: 11/65..  Training loss: 0.47846..
# Epoch: 11/65..  Training loss: 0.47233..
# Epoch: 11/65..  Training loss: 0.46868..
# Epoch: 11/65..  Validation loss: 0.45842..  Pixel accuracy.. 0.86810 Mean IU.. 0.19707
# Epoch: 12/65..  Training loss: 0.46637..
# Epoch: 12/65..  Training loss: 0.45783..
# Epoch: 12/65..  Training loss: 0.44980..
# Epoch: 12/65..  Training loss: 0.44722..
# Epoch: 12/65..  Validation loss: 0.43809..  Pixel accuracy.. 0.86961 Mean IU.. 0.20098
# Epoch: 13/65..  Training loss: 0.44236..
# Epoch: 13/65..  Training loss: 0.43886..
# Epoch: 13/65..  Training loss: 0.43310..
# Epoch: 13/65..  Training loss: 0.42434..
# Epoch: 13/65..  Validation loss: 0.41853..  Pixel accuracy.. 0.87521 Mean IU.. 0.21101
# Epoch: 14/65..  Training loss: 0.42817..
# Epoch: 14/65..  Training loss: 0.41580..
# Epoch: 14/65..  Training loss: 0.40969..
# Epoch: 14/65..  Training loss: 0.41538..
# Epoch: 14/65..  Validation loss: 0.39975..  Pixel accuracy.. 0.87998 Mean IU.. 0.22729
# Epoch: 15/65..  Training loss: 0.40302..
# Epoch: 15/65..  Training loss: 0.39817..
# Epoch: 15/65..  Training loss: 0.39364..
# Epoch: 15/65..  Training loss: 0.37963..
# Epoch: 15/65..  Validation loss: 0.37945..  Pixel accuracy.. 0.85154 Mean IU.. 0.21133
# Epoch: 16/65..  Training loss: 0.38238..
# Epoch: 16/65..  Training loss: 0.37543..
# Epoch: 16/65..  Training loss: 0.37271..
# Epoch: 16/65..  Training loss: 0.36831..
# Epoch: 16/65..  Validation loss: 0.35878..  Pixel accuracy.. 0.85697 Mean IU.. 0.20610
# Epoch: 17/65..  Training loss: 0.36103..
# Epoch: 17/65..  Training loss: 0.35755..
# Epoch: 17/65..  Training loss: 0.34941..
# Epoch: 17/65..  Training loss: 0.33950..
# Epoch: 17/65..  Validation loss: 0.33658..  Pixel accuracy.. 0.86957 Mean IU.. 0.22989
# Epoch: 18/65..  Training loss: 0.34253..
# Epoch: 18/65..  Training loss: 0.33258..
# Epoch: 18/65..  Training loss: 0.33132..
# Epoch: 18/65..  Training loss: 0.31883..
# Epoch: 18/65..  Validation loss: 0.31225..  Pixel accuracy.. 0.87152 Mean IU.. 0.21704
# Epoch: 19/65..  Training loss: 0.31623..
# Epoch: 19/65..  Training loss: 0.31632..
# Epoch: 19/65..  Training loss: 0.30668..
# Epoch: 19/65..  Training loss: 0.30310..
# Epoch: 19/65..  Validation loss: 0.31267..  Pixel accuracy.. 0.88087 Mean IU.. 0.23012
# Epoch: 20/65..  Training loss: 0.30085..
# Epoch: 20/65..  Training loss: 0.29400..
# Epoch: 20/65..  Training loss: 0.28665..
# Epoch: 20/65..  Training loss: 0.28267..
# Epoch: 20/65..  Validation loss: 0.27803..  Pixel accuracy.. 0.88063 Mean IU.. 0.23495
# Epoch: 21/65..  Training loss: 0.27677..
# Epoch: 21/65..  Training loss: 0.27533..
# Epoch: 21/65..  Training loss: 0.26849..
# Epoch: 21/65..  Training loss: 0.26466..
# Epoch: 21/65..  Validation loss: 0.25710..  Pixel accuracy.. 0.88730 Mean IU.. 0.24405
# Epoch: 22/65..  Training loss: 0.25994..
# Epoch: 22/65..  Training loss: 0.25494..
# Epoch: 22/65..  Training loss: 0.25767..
# Epoch: 22/65..  Training loss: 0.24312..
# Epoch: 22/65..  Validation loss: 0.24048..  Pixel accuracy.. 0.88408 Mean IU.. 0.23782
# Epoch: 23/65..  Training loss: 0.24161..
# Epoch: 23/65..  Training loss: 0.23743..
# Epoch: 23/65..  Training loss: 0.23937..
# Epoch: 23/65..  Training loss: 0.22684..
# Epoch: 23/65..  Validation loss: 0.22318..  Pixel accuracy.. 0.89139 Mean IU.. 0.25116
# Epoch: 24/65..  Training loss: 0.22594..
# Epoch: 24/65..  Training loss: 0.22208..
# Epoch: 24/65..  Training loss: 0.21253..
# Epoch: 24/65..  Training loss: 0.21316..
# Epoch: 24/65..  Validation loss: 0.20596..  Pixel accuracy.. 0.89102 Mean IU.. 0.25230
# Epoch: 25/65..  Training loss: 0.21057..
# Epoch: 25/65..  Training loss: 0.20252..
# Epoch: 25/65..  Training loss: 0.20198..
# Epoch: 25/65..  Training loss: 0.19759..
# Epoch: 25/65..  Validation loss: 0.19189..  Pixel accuracy.. 0.88578 Mean IU.. 0.24589
# Epoch: 26/65..  Training loss: 0.19406..
# Epoch: 26/65..  Training loss: 0.18831..
# Epoch: 26/65..  Training loss: 0.18367..
# Epoch: 26/65..  Training loss: 0.18258..
# Epoch: 26/65..  Validation loss: 0.17584..  Pixel accuracy.. 0.89279 Mean IU.. 0.25262
# Epoch: 27/65..  Training loss: 0.18229..
# Epoch: 27/65..  Training loss: 0.17419..
# Epoch: 27/65..  Training loss: 0.16974..
# Epoch: 27/65..  Training loss: 0.16514..
# Epoch: 27/65..  Validation loss: 0.16407..  Pixel accuracy.. 0.88867 Mean IU.. 0.25058
# Epoch: 28/65..  Training loss: 0.16317..
# Epoch: 28/65..  Training loss: 0.15776..
# Epoch: 28/65..  Training loss: 0.15496..
# Epoch: 28/65..  Training loss: 0.15106..
# Epoch: 28/65..  Validation loss: 0.14900..  Pixel accuracy.. 0.87054 Mean IU.. 0.21109
# Epoch: 29/65..  Training loss: 0.15282..
# Epoch: 29/65..  Training loss: 0.14415..
# Epoch: 29/65..  Training loss: 0.13887..
# Epoch: 29/65..  Training loss: 0.13788..
# Epoch: 29/65..  Validation loss: 0.13577..  Pixel accuracy.. 0.89032 Mean IU.. 0.25325
# Epoch: 30/65..  Training loss: 0.13778..
# Epoch: 30/65..  Training loss: 0.13373..
# Epoch: 30/65..  Training loss: 0.13018..
# Epoch: 30/65..  Training loss: 0.12841..
# Epoch: 30/65..  Validation loss: 0.12704..  Pixel accuracy.. 0.88695 Mean IU.. 0.24909
# Epoch: 31/65..  Training loss: 0.12722..
# Epoch: 31/65..  Training loss: 0.12439..
# Epoch: 31/65..  Training loss: 0.12093..
# Epoch: 31/65..  Training loss: 0.11812..
# Epoch: 31/65..  Validation loss: 0.11549..  Pixel accuracy.. 0.89159 Mean IU.. 0.26466
# Epoch: 32/65..  Training loss: 0.11745..
# Epoch: 32/65..  Training loss: 0.11015..
# Epoch: 32/65..  Training loss: 0.10857..
# Epoch: 32/65..  Training loss: 0.11032..
# Epoch: 32/65..  Validation loss: 0.10943..  Pixel accuracy.. 0.87761 Mean IU.. 0.25938
# Epoch: 33/65..  Training loss: 0.10899..
# Epoch: 33/65..  Training loss: 0.10318..
# Epoch: 33/65..  Training loss: 0.10198..
# Epoch: 33/65..  Training loss: 0.10021..
# Epoch: 33/65..  Validation loss: 0.09749..  Pixel accuracy.. 0.88524 Mean IU.. 0.25365
# Epoch: 34/65..  Training loss: 0.09919..
# Epoch: 34/65..  Training loss: 0.09616..
# Epoch: 34/65..  Training loss: 0.09190..
# Epoch: 34/65..  Training loss: 0.09481..
# Epoch: 34/65..  Validation loss: 0.08799..  Pixel accuracy.. 0.89532 Mean IU.. 0.27217
# Epoch: 35/65..  Training loss: 0.08978..
# Epoch: 35/65..  Training loss: 0.08910..
# Epoch: 35/65..  Training loss: 0.08873..
# Epoch: 35/65..  Training loss: 0.08435..
# Epoch: 35/65..  Validation loss: 0.08232..  Pixel accuracy.. 0.89621 Mean IU.. 0.27445
# Epoch: 36/65..  Training loss: 0.08154..
# Epoch: 36/65..  Training loss: 0.07478..
# Epoch: 36/65..  Training loss: 0.08331..
# Epoch: 36/65..  Training loss: 0.07487..
# Epoch: 36/65..  Validation loss: 0.07372..  Pixel accuracy.. 0.89324 Mean IU.. 0.26485
# Epoch: 37/65..  Training loss: 0.06995..
# Epoch: 37/65..  Training loss: 0.07016..
# Epoch: 37/65..  Training loss: 0.07234..
# Epoch: 37/65..  Training loss: 0.06909..
# Epoch: 37/65..  Validation loss: 0.07500..  Pixel accuracy.. 0.85076 Mean IU.. 0.25691
# Epoch: 38/65..  Training loss: 0.06716..
# Epoch: 38/65..  Training loss: 0.06340..
# Epoch: 38/65..  Training loss: 0.06414..
# Epoch: 38/65..  Training loss: 0.06138..
# Epoch: 38/65..  Validation loss: 0.06153..  Pixel accuracy.. 0.90245 Mean IU.. 0.28711
# Epoch: 39/65..  Training loss: 0.05977..
# Epoch: 39/65..  Training loss: 0.05717..
# Epoch: 39/65..  Training loss: 0.05869..
# Epoch: 39/65..  Training loss: 0.05971..
# Epoch: 39/65..  Validation loss: 0.05985..  Pixel accuracy.. 0.87579 Mean IU.. 0.26634
# Epoch: 40/65..  Training loss: 0.05930..
# Epoch: 40/65..  Training loss: 0.05758..
# Epoch: 40/65..  Training loss: 0.05459..
# Epoch: 40/65..  Training loss: 0.05492..
# Epoch: 40/65..  Validation loss: 0.05449..  Pixel accuracy.. 0.89054 Mean IU.. 0.28745
# Epoch: 41/65..  Training loss: 0.05030..
# Epoch: 41/65..  Training loss: 0.04878..
# Epoch: 41/65..  Training loss: 0.05052..
# Epoch: 41/65..  Training loss: 0.04610..
# Epoch: 41/65..  Validation loss: 0.04878..  Pixel accuracy.. 0.89859 Mean IU.. 0.29008
# Epoch: 42/65..  Training loss: 0.04664..
# Epoch: 42/65..  Training loss: 0.04887..
# Epoch: 42/65..  Training loss: 0.04750..
# Epoch: 42/65..  Training loss: 0.04451..
# Epoch: 42/65..  Validation loss: 0.04444..  Pixel accuracy.. 0.90517 Mean IU.. 0.30708
# Epoch: 43/65..  Training loss: 0.04248..
# Epoch: 43/65..  Training loss: 0.04280..
# Epoch: 43/65..  Training loss: 0.03998..
# Epoch: 43/65..  Training loss: 0.03804..
# Epoch: 43/65..  Validation loss: 0.04098..  Pixel accuracy.. 0.90401 Mean IU.. 0.30508
# Epoch: 44/65..  Training loss: 0.03863..
# Epoch: 44/65..  Training loss: 0.03733..
# Epoch: 44/65..  Training loss: 0.04212..
# Epoch: 44/65..  Training loss: 0.04694..
# Epoch: 44/65..  Validation loss: 0.03806..  Pixel accuracy.. 0.90387 Mean IU.. 0.30538
# Epoch: 45/65..  Training loss: 0.03471..
# Epoch: 45/65..  Training loss: 0.03572..
# Epoch: 45/65..  Training loss: 0.04651..
# Epoch: 45/65..  Training loss: 0.03530..
# Epoch: 45/65..  Validation loss: 0.03610..  Pixel accuracy.. 0.90494 Mean IU.. 0.31674
# Epoch: 46/65..  Training loss: 0.03430..
# Epoch: 46/65..  Training loss: 0.03329..
# Epoch: 46/65..  Training loss: 0.03061..
# Epoch: 46/65..  Training loss: 0.03023..
# Epoch: 46/65..  Validation loss: 0.03311..  Pixel accuracy.. 0.90113 Mean IU.. 0.30431
# Epoch: 47/65..  Training loss: 0.03054..
# Epoch: 47/65..  Training loss: 0.03178..
# Epoch: 47/65..  Training loss: 0.03032..
# Epoch: 47/65..  Training loss: 0.02966..
# Epoch: 47/65..  Validation loss: 0.03250..  Pixel accuracy.. 0.89733 Mean IU.. 0.30711
# Epoch: 48/65..  Training loss: 0.02786..
# Epoch: 48/65..  Training loss: 0.02950..
# Epoch: 48/65..  Training loss: 0.03079..
# Epoch: 48/65..  Training loss: 0.03793..
# Epoch: 48/65..  Validation loss: 0.02885..  Pixel accuracy.. 0.91051 Mean IU.. 0.32677
# Epoch: 49/65..  Training loss: 0.02703..
# Epoch: 49/65..  Training loss: 0.02731..
# Epoch: 49/65..  Training loss: 0.02771..
# Epoch: 49/65..  Training loss: 0.02388..
# Epoch: 49/65..  Validation loss: 0.03056..  Pixel accuracy.. 0.89247 Mean IU.. 0.31273
# Epoch: 50/65..  Training loss: 0.02592..
# Epoch: 50/65..  Training loss: 0.02481..
# Epoch: 50/65..  Training loss: 0.02074..
# Epoch: 50/65..  Training loss: 0.02679..
# Epoch: 50/65..  Validation loss: 0.02601..  Pixel accuracy.. 0.91015 Mean IU.. 0.33319
# Epoch: 51/65..  Training loss: 0.02844..
# Epoch: 51/65..  Training loss: 0.02158..
# Epoch: 51/65..  Training loss: 0.02487..
# Epoch: 51/65..  Training loss: 0.02354..
# Epoch: 51/65..  Validation loss: 0.02455..  Pixel accuracy.. 0.91284 Mean IU.. 0.33899
# Epoch: 52/65..  Training loss: 0.02187..
# Epoch: 52/65..  Training loss: 0.02345..
# Epoch: 52/65..  Training loss: 0.02008..
# Epoch: 52/65..  Training loss: 0.02193..
# Epoch: 52/65..  Validation loss: 0.02367..  Pixel accuracy.. 0.91100 Mean IU.. 0.33784
# Epoch: 53/65..  Training loss: 0.02020..
# Epoch: 53/65..  Training loss: 0.02179..
# Epoch: 53/65..  Training loss: 0.01911..
# Epoch: 53/65..  Training loss: 0.02363..
# Epoch: 53/65..  Validation loss: 0.02287..  Pixel accuracy.. 0.91124 Mean IU.. 0.33773
# Epoch: 54/65..  Training loss: 0.01783..
# Epoch: 54/65..  Training loss: 0.01982..
# Epoch: 54/65..  Training loss: 0.01947..
# Epoch: 54/65..  Training loss: 0.02577..
# Epoch: 54/65..  Validation loss: 0.02282..  Pixel accuracy.. 0.90817 Mean IU.. 0.33993
# Epoch: 55/65..  Training loss: 0.01824..
# Epoch: 55/65..  Training loss: 0.02164..
# Epoch: 55/65..  Training loss: 0.02682..
# Epoch: 55/65..  Training loss: 0.01630..
# Epoch: 55/65..  Validation loss: 0.04411..  Pixel accuracy.. 0.76205 Mean IU.. 0.21759
# Epoch: 56/65..  Training loss: 0.02455..
# Epoch: 56/65..  Training loss: 0.01755..
# Epoch: 56/65..  Training loss: 0.01607..
# Epoch: 56/65..  Training loss: 0.01798..
# Epoch: 56/65..  Validation loss: 0.01976..  Pixel accuracy.. 0.91405 Mean IU.. 0.34688
# Epoch: 57/65..  Training loss: 0.02037..
# Epoch: 57/65..  Training loss: 0.01540..
# Epoch: 57/65..  Training loss: 0.02995..
# Epoch: 57/65..  Training loss: 0.01703..
# Epoch: 57/65..  Validation loss: 0.02131..  Pixel accuracy.. 0.90412 Mean IU.. 0.33314
# Epoch: 58/65..  Training loss: 0.02186..
# Epoch: 58/65..  Training loss: 0.01371..
# Epoch: 58/65..  Training loss: 0.01605..
# Epoch: 58/65..  Training loss: 0.01574..
# Epoch: 58/65..  Validation loss: 0.02145..  Pixel accuracy.. 0.89652 Mean IU.. 0.33732
# Epoch: 59/65..  Training loss: 0.01853..
# Epoch: 59/65..  Training loss: 0.01493..
# Epoch: 59/65..  Training loss: 0.01579..
# Epoch: 59/65..  Training loss: 0.02495..
# Epoch: 59/65..  Validation loss: 0.01907..  Pixel accuracy.. 0.90965 Mean IU.. 0.33738
# Epoch: 60/65..  Training loss: 0.01770..
# Epoch: 60/65..  Training loss: 0.01445..
# Epoch: 60/65..  Training loss: 0.01416..
# Epoch: 60/65..  Training loss: 0.01505..
# Epoch: 60/65..  Validation loss: 0.01840..  Pixel accuracy.. 0.91203 Mean IU.. 0.35308
# Epoch: 61/65..  Training loss: 0.01848..
# Epoch: 61/65..  Training loss: 0.01400..
# Epoch: 61/65..  Training loss: 0.01544..
# Epoch: 61/65..  Training loss: 0.01551..
# Epoch: 61/65..  Validation loss: 0.01810..  Pixel accuracy.. 0.90929 Mean IU.. 0.34767
# Epoch: 62/65..  Training loss: 0.01290..
# Epoch: 62/65..  Training loss: 0.01272..
# Epoch: 62/65..  Training loss: 0.01845..
# Epoch: 62/65..  Training loss: 0.01423..
# Epoch: 62/65..  Validation loss: 0.02739..  Pixel accuracy.. 0.86593 Mean IU.. 0.29588
# Epoch: 63/65..  Training loss: 0.02584..
# Epoch: 63/65..  Training loss: 0.01427..
# Epoch: 63/65..  Training loss: 0.01316..
# Epoch: 63/65..  Training loss: 0.01073..
# Epoch: 63/65..  Validation loss: 0.01747..  Pixel accuracy.. 0.91252 Mean IU.. 0.34892
# Epoch: 64/65..  Training loss: 0.01211..
# Epoch: 64/65..  Training loss: 0.01138..
# Epoch: 64/65..  Training loss: 0.01427..
# Epoch: 64/65..  Training loss: 0.01312..
# Epoch: 64/65..  Validation loss: 0.01682..  Pixel accuracy.. 0.91390 Mean IU.. 0.35408
# Epoch: 65/65..  Training loss: 0.01290..
# Epoch: 65/65..  Training loss: 0.01140..
# Epoch: 65/65..  Training loss: 0.01188..
# Epoch: 65/65..  Training loss: 0.01693..
# Epoch: 65/65..  Validation loss: 0.01870..  Pixel accuracy.. 0.90202 Mean IU.. 0.34651

# %% [markdown]
# ### Check accuracy after training

# %%
model.eval()
with torch.no_grad():
  pixel_acc, mean_iou = validation(model, validloader, criterion)

print("Pixel accuracy: ", pixel_acc, " Mean IoU: ", mean_iou)
# Out:
# Pixel accuracy:  0.8929748180192072  Mean IoU:  0.2560160674717217
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice

# %% [markdown]
# ### Visualization

# %%
#Training Loss
pd.read_csv("/content/drive/My Drive/trn_loss_modified_architecture1.1_65epoch.csv")

# %%
#Validation Loss
pd.read_csv("/content/drive/My Drive/val_loss_modified_architecture1.1_65epoch.csv")

# %%
#Mean IOU
pd.read_csv("/content/drive/My Drive/meaniou_modified_architecture1.1_65epoch.csv")

# %% [markdown]
# Training Loss PLot

# %%
plt.plot(train_losses_epoch, label='Training loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Make inference

# %%
n_classes = 32
model = FCN8s(VGG16(cfg, ranges), n_classes)
state_dict = torch.load("/content/drive/My Drive/fcn-model-modified_architecture1.1_65epoch.pth")
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
def plot_imgs(images = [], titles = [], figsize = (10,10)):
  size = len(images)
  fig = plt.figure(figsize=figsize)
  i = 1
  for image in images:
    ax = fig.add_subplot(1,size,i)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(titles[i-1])
    ax.imshow(image)
    i += 1
  return None
  
#Id : [Label, (RGB code)]
gt_labels = {1 : ["Animal", (64, 128, 64)],
            2 : ["Archway", (192, 0, 128)],
            3 : ["Bicyclist", (0, 128, 192)],
            4 : ["Bridge", (0, 128, 64)],
            5 : ["Building", (128, 0, 0,)],
            6 : ["Car", (64, 0, 128)],
            7 : ["CartLuggagePram", (64, 0, 192)],
            8 : ["Child", (192, 128, 64)],
            9 : ["Column_Pole", (192, 192, 128)],
            10: ["Fence", (64, 64, 128)],
            11: ["LaneMkgsDriv", (128, 0, 192)],
            12: ["LaneMkgsNonDriv", (192, 0, 64)],
            13: ["Misc_Text", (128, 128, 64)],
            14: ["MotorcycleScooter", (192, 0, 192)],
            15: ["OtherMoving", (128, 64, 64)],
            16: ["ParkingBlock", (64, 192, 128)],
            17: ["Pedestrian", (64, 64, 0)],
            18: ["Road", (128, 64, 128)],
            19: ["RoadShoulder", (128, 128, 192)],
            20: ["Sidewalk", (0, 0, 192)],
            21: ["SignSymbol", (192, 128, 128)],
            22: ["Sky", (128, 128, 128)],
            23: ["SUVPickupTruck", (64, 128, 192)],
            24: ["TrafficCone", (0, 0, 64)],
            25: ["TrafficLight", (0, 64, 64)],
            26: ["Train", (192, 64, 128)],
            27: ["Tree", (128, 128, 0)],
            28: ["Truck_Bus", (192, 128, 192)],
            29: ["Tunnel", (64, 0, 64)],
            30: ["VegetationMisc", (192, 192, 0)],
            31: ["Void", (0, 0, 0)],
            32: ["Wall", (64, 192, 0)]}

# %%
from PIL import Image
import warnings

warnings.filterwarnings("ignore")

inference_transforms = transforms.Compose([ transforms.Resize((704,960)),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.460],[0.229, 0.224, 0.225])])
def load_image(image):
  if isinstance(image, str):
    image = Image.open(image).convert('RGB')
  else:
    image = Image.fromarray(image).convert('RGB')
  image = inference_transforms(image)
  image = torch.tensor(image, requires_grad=False)
  image = image.unsqueeze(0)
  return image

def get_predicted_image(original, prediction, labels=None):
  _, h, w = prediction.shape
  _, oh, ow = original.shape
  if h != oh or w != ow:
    original =np.array(Image.fromarray(original).resize(size=(704, 960))) #scipy.misc.imresize(original, (704, 960))
  output = np.zeros((h, w, 3), dtype=np.uint8)
  for i in range(h):
    for j in range(w):
      index = prediction[0][i][j] + 1
      try:
        if labels is not None:
          if index in labels:
            color = gt_labels.get(index)[1]
            output[i, j, 0] = color[0]
            output[i, j, 1] = color[1]
            output[i, j, 2] = color[2]
          else:
            output[i, j, 0] = original[i, j, 0]
            output[i, j, 1] = original[i, j, 1]
            output[i, j, 2] = original[i, j, 2]
        else:
          color = gt_labels.get(index)[1]
          output[i, j, 0] = color[0]
          output[i, j, 1] = color[1]
          output[i, j, 2] = color[2]
      except:
        print("Upss, didn't work")
        break
  return output

def get_image_labels(testimage):
  model.to(device)
  model.eval()
  image = load_image(testimage)
  prediction = model(image.to(device))
  prediction = prediction.data.cpu().numpy()
  N, _, h, w = prediction.shape
  prediction = prediction.transpose(0, 2, 3, 1).reshape(-1, 32).argmax(axis=1).reshape(N, h, w)
  return prediction

# %% [markdown]
# ### Compare prediction with ground truth

# %%
name = "Seq05VD_f04050"

inp_image = "/content/drive/My Drive/CamVid/train/" + name + ".png"
tru_image = "/content/drive/My Drive/CamVid/train_labels/" + name + "_L.png"

original = imageio.imread(inp_image)
truth = imageio.imread(tru_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))

plot_imgs([original, truth, predicted], ["Original", "Ground truth", "Prediction"], (15, 15))

# %%
name = ["0006R0_f01920","0006R0_f02790","0016E5_06330","0016E5_07800"]
for nam in name:
  inp_image = "/content/drive/My Drive/CamVid/val/" + nam + ".png"
  #tru_image = "/content/drive/My Drive/CamVid/val_labels/" + nam + "_L.png"

  prd=get_predicted_image(imageio.imread(inp_image), get_image_labels(inp_image))
  plot_imgs([prd], [""], (15, 15))

# %%
name = ["0006R0_f01920","0006R0_f02790","0016E5_06330","0016E5_07800"]
for nam in name:
  inp_image = "/content/drive/My Drive/CamVid/val/" + nam + ".png"
  tru_image = "/content/drive/My Drive/CamVid/val_labels/" + nam + "_L.png"

  original = imageio.imread(inp_image)
  truth = imageio.imread(tru_image)
  predicted = get_predicted_image(original, get_image_labels(inp_image))

  plot_imgs([original, truth, predicted], ["Original", "Ground truth", "Prediction"], (15, 15))

# %% [markdown]
# ### Predict on an unlabeled image

# %%
name = ["/content/drive/My Drive/CamVid/City_Road_Cardiff.jpg",
        "/content/drive/My Drive/CamVid/City-Road-in-Cardiff2.jpg",
        "/content/drive/My Drive/CamVid/Road US.jpg"]
for inp_image in name:

  prd=get_predicted_image(imageio.imread(inp_image), get_image_labels(inp_image))
  plot_imgs([prd], ["Prediction"], (15, 15))

# %%
inp_image = "/content/drive/My Drive/CamVid/City_Road_Cardiff.jpg"

original = imageio.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %%
inp_image = "/content/drive/My Drive/CamVid/City-Road-in-Cardiff2.jpg"

original = imageio.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %%
inp_image = "/content/drive/My Drive/CamVid/Road US.jpg"

original = imageio.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %% [markdown]
# ### Segment a selected group of labels

# %%
name = "Seq05VD_f01800"

inp_image = "data/CamVid/701_StillsRaw_full/" + name + ".png"
tru_image = "data/CamVid/LabeledApproved_full/" + name + "_L.png"

original = scipy.misc.imread(inp_image)
truth = scipy.misc.imread(tru_image)
predicted = get_predicted_image(original, get_image_labels(inp_image), [11, 12, 18, 19]) # Only road labels

plot_imgs([original, truth, predicted], ["Original", "Ground truth", "Prediction"], (15, 15))

# %%
inp_image = "data/testimage2.png"

original = scipy.misc.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image), [11, 12, 18, 19]) # Only road labels
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %% [markdown]
# ### Inference on video

# %%
import glob
import os 
import cv2

def get_frame_rate(video):
    video = cv2.VideoCapture(video);
    # Find OpenCV version
    (major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
    if int(major_ver)  < 3 :
        fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
        print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(int(fps)))
    else :
        fps = video.get(cv2.CAP_PROP_FPS)
        print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(int(fps)))
    video.release();
    return int(fps)
    
def process_video(video, path_to_save):
    cap = cv2.VideoCapture(video)
    print("Number of frames: ", int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
    ret, frame = cap.read()
    cont = 0
    while ret:
        if cont > 17100 and cont < 17710:
          #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
          prediction = get_predicted_image(frame, get_image_labels(frame), [11, 12, 18, 19]) # Only road labels
          cv2.imwrite(path_to_save + str(cont) + ".png", prediction)
        cont += 1
        ret, frame = cap.read()
    print("Video processed.")

def make_video(outvid, images=None, fps=30, size=None, is_color=True, format="FMP4"):
    fourcc = cv2.VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = cv2.imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = cv2.VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = cv2.resize(img, size)
        vid.write(img)
    vid.release()
    return vid
    
def detect_on_video(video, out_path, fps):
    # Process video to get all the frames with detections
    process_video(video, out_path)
    # Get processed frames and order by name
    images = list(glob.iglob(os.path.join(out_path, '*.png')))
    images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))
    # Create the video from processed frames
    make_video(out_path+"output.mp4", images, fps)
    print("Video: "+ out_path +" output.mp4 it's ready")

video = './../YOLO/images/timelapse.mp4'
path = './data/processed/'

fps = get_frame_rate(video)
detect_on_video(video, path, fps+1)
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 29
# Number of frames:  22339
# Video processed.
# Video: ./data/processed/ output.mp4 it's ready

# %% [markdown]
# ### Video output (converted as GIF)

# %% [markdown]
# ![Video-output](/images/outputgif.gif)
