# %% [markdown]
# # Fully convolutional network for semantic segmentation
#
# Semantic segmentation belongs to scene understanding field, and it is the task of assigning meaning to a part of an object. This can be done at the pixel level where we assign each pixel to a target class.
#
# The goal is to input an image into a neural network and output a category for every pixel. We'll have a set of categories, much like in a classification task. But instead of assigning a single class to an image we want to assign a class to every pixel in that image.
#
# FCNs achieves state-of-art in tasks like semantic segmentation, by taking advantage of three special techniques:
# - Replace fully connected layers with one by one convolutional layer.
# - Up-sampling through the use of transposed convolutional layers.
# - Adding skip connections. (This allows the network to use information from multiple resolution scales)
#
# This network takes in an image that has true labels attached to each pixel and then it outputs a tensor with dimension:``` classes x height x width. ```
#
# **FCN limitations**
#
# - It is very expensive to label every pixel.
# - It is computationally expensive to maintain spatial information in each convolutional layer.

# %% [markdown]
# ## Set up Google Colab

# %% [markdown]
# ### Connect with Google drive

# %%
from google.colab import files
train = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Go to the project directory

# %%
# %cd "/content/drive/My Drive/"
# %ls
# Out:
# /content/drive/My Drive
#  CamVid/
# 'Case Study'/
# 'Colab Notebooks'/
# 'Data Science'/
#  Dissertation/
#  fcn-model-50Epoch.pth
#  fcn-model-55Epoch.pth
#  fcn-model-meaniuo-55Epoch.pth
#  fcn-model-meaniuo.pth
#  fcn-model-modified_architecture1.1.pth
#  fcn-model-modified_architecture1.2.pth
#  fcn-model-modified_architecture1.3.pth
#  fcn-model-modified_architecture1.pth
#  fcn-model-modified_architecture2.pth
#  fcn-model-original1.1.pth
#  fcn-model-original-lasttraining.pth
#  fcn-model.pth
#  fcn-modified-model1.pth
#  fcn-modified-model2.pth
#  Glasgow.rar
# 'Hands-On Machine Learning with Scikit-Learn and TensorFlow_ Concepts, Tools, and Techniques to Build Intelligent Systems-Aurélien Géron - (2017).pdf'
#  Handycam/
# 'How to get started with Drive.pdf'
# 'Introduction to Machine Learning with Python  A Guide for Data Scientists-Andreas C. Muller, Sarah Guido - (2016).pdf'
#  Law/
#  MATLAB/
# 'My Schedule.gsheet'
#  Photo/
#  Presentation/
#  Proposal/
# 'Pytorch Visualization'/
#  train_path2.csv
#  Transcript.pdf
#  trn_loss_modified_architecture1.1.csv
#  trn_loss_modified_architecture1.2.csv
#  trn_loss_modified_architecture1.2.npy
#  trn_loss_modified_architecture1.3.csv
#  trn_loss_modified_architecture1.3.npy
#  trn_loss_original.csv
#  trn_loss_original.npy
#  val_loss_modified_architecture1.1.csv
#  val_loss_modified_architecture1.2.csv
#  val_loss_modified_architecture1.2.npy
#  val_loss_modified_architecture1.3.csv
#  val_loss_modified_architecture1.3.npy
#  val_loss_original.csv
#  val_loss_original.npy
#  val_path2.csv
#  Video/

# %% [markdown]
# ### Install packages

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline 


import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
import pandas as pd
import scipy.misc
import imageio
import random

import torch
import torch.nn as nn
import torch.functional as F
from torch import optim

import torchvision
from torchvision import models, datasets, transforms, utils
from torchvision.models.vgg import VGG
from torch.utils.data import Dataset

import torch.utils.data as data
import glob
import cv2
import os
import io
from PIL import Image

from statistics import mean

#import albumentations as A
#from pytorch_toolbelt.utils import fs

# %% [markdown]
# ## Data
#
# [CamVid](http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamVid/) is a motion-based segmentation and recognition [dataset](https://github.com/mostafaizz/camvid) that contains 701 images, 701 labeled images, and a file with a list of classes with their correspondence in RGB code.
#
# **NOTE:**
# I pre-processed the labeled images by changing their RGB values for class ids. Instead of doing it directly on the CamVid class, do it separately and save the result as a .npy file to improve the performance ([Here](https://towardsdatascience.com/why-you-should-start-using-npy-file-more-often-df2a13cc0161) is an interesting article about that). In this way you cannot use PyTorch transforms on a label image, since PIL will change the class id for color values. Also, CamVid images are very similar, so adding augmentation like RandomCrop or RandomHorizontalFlip helps the network.

# %% [markdown]
# ### Load data

# %%
class CamVid(Dataset):
  
  def __init__(self, csv_file, phase):
    self.phase = phase
    self.data = pd.read_csv(csv_file)
    
    if phase == 'train':
        self.input_shape = (576, 768)
    elif phase == 'valid':
        self.input_shape = (704, 960)
  
  def __getitem__(self, index):
    image, label = self.data.iloc[index, 1], self.data.iloc[index, 2]
    image = imageio.imread(image,pilmode="RGB")
    label = np.load(label)
        
    if self.phase == "train":
         # RandomCrop
        h, w, _ = image.shape
        new_h, new_w = self.input_shape
        top = random.randint(0, h - new_h)
        left = random.randint(0, w - new_w)
        image = image[top:top + new_h, left:left + new_w]
        label = label[top:top + new_h, left:left + new_w]
      
      # RandomHorizontalFlip
    if random.random() < 0.5:
        image = np.fliplr(image)
        label = np.fliplr(label)
        
    if self.phase == "valid":
      # "Resize"
        new_h, new_w = self.input_shape
        image = image[0:new_h, 0:new_w]
        label = label[0:new_h, 0:new_w]
          
    # Normalization 
    mean=[0.485, 0.456, 0.460]
    std =[0.229, 0.224, 0.225]
    
    image = np.transpose(image, (2, 0, 1)) / 255.
    image[0] = (image[0] - mean[0]) / std[0]
    image[1] = (image[1] - mean[1]) / std[1]
    image[2] = (image[2] - mean[2]) / std[2]
    
    # ToTensor 
    image = torch.from_numpy(image.copy()).float()
    label = torch.from_numpy(label.copy()).long()
  
    # One-hot encoding 
    h, w = label.size()
    target = torch.zeros(32, h, w)
    for c in range(32):
        target[c][label == c] = 1
        
    return {'x': image, 'y':target, 'l':label} 

  def __len__(self):
    return len(self.data)

# %%
train_data = CamVid("/content/drive/My Drive/train_path2.csv", phase="train")
valid_data = CamVid("/content/drive/My Drive/val_path2.csv", phase="valid")

trainloader = torch.utils.data.DataLoader(train_data, batch_size=5, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=1)

# %% [markdown]
# ### Visualize a single batch

# %%
def show_batch(batch):
  mean=[0.485, 0.456, 0.460]
  std =[0.229, 0.224, 0.225]
  
  img_batch = batch['x']
 
  # Desnormalize 
  img_batch[:,0,...].mul_(std[0]).add_(mean[0])
  img_batch[:,1,...].mul_(std[1]).add_(mean[1])
  img_batch[:,2,...].mul_(std[2]).add_(mean[2])
  
  img_batch = np.clip(img_batch, 0, 1)
  grid = utils.make_grid(img_batch)
  
  plt.rcParams['figure.figsize'] = [20, 7.0]
  plt.figure()
  plt.title('Batch from training data')
  plt.imshow(grid.numpy().transpose((1, 2, 0)))
  plt.axis('off')
  plt.ioff()
  plt.show
    
batch = next(iter(trainloader))
print(batch['x'].size(), batch['y'].size(), batch['l'].size())
show_batch(batch)
# Out:
# torch.Size([5, 3, 576, 768]) torch.Size([5, 32, 576, 768]) torch.Size([5, 576, 768])

# %% [markdown]
# ## Model

# %% [markdown]
# ### Encoder
#
# Its goal is to extract features from the image. In this case, I used the pretrained VGG16 model and removed the classifier (the fully connected layer at the end).  Doing so casts it into a fully convolutional network that outputs classification maps (heatmaps). Also saved the score of three different pooling layers that the decoder will use to perform skip connections.

# %%
class VGG16(VGG):
  
  def __init__(self, cfg, ranges, pretrained=True, model='vgg16', requires_grad=True, remove_fc=True, show_params=False):
    super().__init__(self.make_layers(cfg[model]))
    
    self.ranges = ranges[model]
        
    if pretrained:
      exec("self.load_state_dict(models.%s(pretrained=True).state_dict())" % model) #Loading all weights 
    if not requires_grad:
      for parameter in super().parameters(): # False if you want to freeze the encoder and avoid to train it.
        parameter.requires_grad = False
    if remove_fc: 
      del self.classifier
      del self.avgpool
    if show_params:  # Display the params to see the dimensionallity
      for name, parameter in self.named_parameters():
        print(name, parameter.size())
        
  def forward(self, x):
    output = {}
    
    # Get the output of each maxpooling layer (There are 5 in VGG) to create skip connections.
    for idx in range(len(self.ranges)): #range is below the decoder: ranges = {'vgg16': ((0, 5), (5, 10), (10, 17), (17, 24), (24, 31))}
      for layer in range(self.ranges[idx][0], self.ranges[idx][1]):
        x = self.features[layer](x)
      output["pool%d"%(idx+1)] = x #naming the layer:pool(index+1)
    
    return output 
  
  def make_layers(self, cfg, batch_norm=False):
    layers = []
    in_channels = 3
    for v in cfg:   #cfg = {'vgg16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],}
      if v == 'M':
        layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
      else:
        conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
        if batch_norm:
          layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
        else:
          layers += [conv2d, nn.ReLU(inplace=True)]
        in_channels = v
    return nn.Sequential(*layers)

# %%
ranges = {'vgg16': ((0, 5), (5, 10), (10, 17), (17, 24), (24, 31))} #up to each maxpooling layer
cfg = {'vgg16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],}

# %%
VGG16(cfg,ranges)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# VGG16(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ### Decoder
#
# It up-scales the output of the encoder such that it's the same size as the original image.
#
# - **Convolutional score layer** - This will result in the output of a 4D tensor instead of a flattened 2D tensor, so spatial information will be preserved. Effectively, this turns convolutions into a matrix multiplication with spatial information. The number of kernels is equivalent to the number of outputs.
#
# - **Transposed convolutions** - Is essentially a reverse convolution in which the forward and the backward passes are swapped. They help in upsampling the previous layer to a higher resolution or dimension.
#
# - **Skip connections** - They allow the network to use information from multiple resolutions, and as a result, the network is able to make more precise segmentation decisions.

# %%
class FCN8s(nn.Module):
  
  def __init__(self, pretrained_model, n_classes):
    super().__init__()
    
    self.n_classes = n_classes
    self.pretrained_model = pretrained_model
    #Convolutional layers
    self.relu = nn.ReLU(inplace=True)

    #Extra layers
    self.conv1= nn.Conv2d(512,640,kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    self.conv2= nn.Conv2d(640,640,kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    self.conv3=nn.Conv2d(640,640,kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
    self.pool6=nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)

    self.conv4 = nn.Conv2d(in_channels=640, out_channels=4096, kernel_size=7, padding=3)
    self.dropout1 = nn.Dropout(0.85)

    self.conv5 = nn.Conv2d(in_channels=4096, out_channels=4096, kernel_size=1)
    self.dropout2 = nn.Dropout(0.85)

    self.conv6 = nn.Conv2d(in_channels=4096, out_channels=n_classes, kernel_size=1)
    
    # Transposed convolutions (to upsampling previous layers)
    self.deconv1 = nn.ConvTranspose2d(in_channels=n_classes, out_channels=512, kernel_size=4, stride=2, padding=1)
    self.bn1 = nn.BatchNorm2d(512)
    self.deconv2 = nn.ConvTranspose2d(in_channels=512, out_channels=512, kernel_size=4, stride=2, padding=1)
    self.bn2 = nn.BatchNorm2d(512)
    self.deconv3 = nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=4, stride=2, padding=1)
    self.bn3 = nn.BatchNorm2d(256)
    self.deconv4 = nn.ConvTranspose2d(in_channels=256, out_channels=n_classes, kernel_size=16, stride=8, padding=4)
    self.bn4 = nn.BatchNorm2d(n_classes)
    # Convolutional score layer (replace the FC layers)
    self.score = nn.Conv2d(n_classes, n_classes, 1)
  
  def forward(self, x):
    x = self.pretrained_model(x)
    
    # Skip connections (connect the output of one layer to a non-adjacent layer)
    pool_5 = x['pool5']
    pool_4 = x['pool4']
    pool_3 = x['pool3']
    
    x = self.relu(self.conv1(pool_5))
    x = self.relu(self.conv2(x))
    x = self.relu(self.conv3(x))
    pool_6 =self.pool6(x)
    
    x = self.dropout1(self.relu(self.conv4(pool_6)))
    x = self.dropout2(self.relu(self.conv5(x)))
    x = self.relu(self.conv6(x))

    x = self.relu(self.deconv1(x))
    x = self.bn1(x + pool_5)
    x = self.relu(self.deconv2(x))
    x = self.bn2(x + pool_4)
    x = self.relu(self.deconv3(x))
    x = self.bn3(x+pool_3)
    x = self.bn4(self.relu(self.deconv4(x)))
    x = self.score(x)
    
    return x

# %% [markdown]
# ###  Test output sizes

# %%
batch_size, n_classes, h, w = 4, 20, 576, 768

encoder = VGG16(cfg, ranges, requires_grad=True)
decoder = FCN8s(encoder, n_classes)

enc_input = torch.randn(batch_size, 3, 160, 160)
dec_input = torch.randn(batch_size, 3, h, w)

enc_output = encoder(enc_input)
dec_output = decoder(dec_input)

assert enc_output['pool5'].size() == torch.Size([batch_size, 512, 5, 5])
assert dec_output.size() == torch.Size([batch_size, n_classes, h, w])
print("Correct output sizes")
# Out:
# Correct output sizes

# %% [markdown]
# ## Train model

# %% [markdown]
# ### Test if the model works using a single batch

# %%
fcn = FCN8s(VGG16(cfg,ranges), n_classes)
fcn
# Out:
# FCN8s(
#   (pretrained_model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#       (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU(inplace=True)
#       (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (27): ReLU(inplace=True)
#       (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (29): ReLU(inplace=True)
#       (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (relu): ReLU(inplace=True)
#   (conv1): Conv2d(512, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(640, 4096, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (dropout1): Dropout(p=0.85, inplace=False)
#   (conv5): Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1))
#   (dropout2): Dropout(p=0.85, inplace=False)
#   (conv6): Conv2d(4096, 20, kernel_size=(1, 1), stride=(1, 1))
#   (deconv1): ConvTranspose2d(20, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv4): ConvTranspose2d(256, 20, kernel_size=(16, 16), stride=(8, 8), padding=(4, 4))
#   (bn4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (score): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
#fcn.pretrained_model.features[0]=nn.Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %%
fcn = FCN8s(VGG16(cfg,ranges), n_classes)

criterion = nn.BCELoss()
optimizer = optim.SGD(fcn.parameters(), lr=0.01, momentum=0.9)

x = torch.randn(batch_size, 3, h, w)
y = torch.randn(batch_size, n_classes, h, w)
y = torch.tensor(y, requires_grad=False)

for i in range(3):
  optimizer.zero_grad()
  output = fcn(x)
  output = torch.sigmoid(output)
  loss = criterion(output, y)
  loss.backward()
  print("i: {}, loss: {:.5f}".format(i, loss.item()))
  optimizer.step()

# %% [markdown]
# ### Set training parameters

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# Define model
n_classes = 32
model = FCN8s(VGG16(cfg, ranges), n_classes)

#state_dict = torch.load("/content/drive/My Drive/fcn-model.pth")
#model.load_state_dict(state_dict)

model.to(device)

# Define training parameters
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.RMSprop(model.parameters(), lr=0.0001, momentum=0.5, weight_decay=1e-5) #changing momentum
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.5)
epochs = 65
print_every = 20

# Define scores
IoU_scores = np.zeros((epochs, n_classes))
pixel_scores = np.zeros(epochs)

# %% [markdown]
# ### Check accuracy before training

# %%
def iou(y_hat, y):
  ious = []
  for c in range(n_classes):
    pred_inds = y_hat == c
    target_inds = y == c
    intersection = pred_inds[target_inds].sum() # the intersection based of false or true scale which if pred=true and inds=false then the outcome would be empty and summing up elements to get the number of intersction points (True)
    union = pred_inds.sum() + target_inds.sum() - intersection
    if union == 0:
      ious.append(float('nan')) # If there is no ground truth, do not include in evaluation
    else:
      ious.append(float(intersection) / float(max(union, 1)))
  return ious

def pixel_accuracy(y_hat, y):
  correct = (y_hat == y).sum()
  total = (y == y).sum()
  return correct/total


def validation(model, validloader, criterion):
  total_ious = []
  pixel_accs = []
  for i, batch in enumerate(validloader):
    inputs = batch['x'].to(device)
    output = model(inputs)
    output = output.data.cpu().numpy()
        
    N, _, h, w = output.shape 
    pred = output.transpose(0, 2, 3, 1).reshape(-1, n_classes).argmax(axis=1).reshape(N, h, w) #transposing 32 class at the end and reshape it to collect all data in 32 classes then taking maximum value of each class
    target = batch['l'].cpu().numpy().reshape(N, h, w)
    
    for y_hat, y in zip(pred, target):
      total_ious.append(iou(y_hat, y))
      pixel_accs.append(pixel_accuracy(y_hat, y))
  
  # Pixel accuracy
  pixel_acc = np.array(pixel_accs).mean()
  
  # Mean IoU
  total_ious = np.array(total_ious).T
  mean_iou = np.nanmean(np.nanmean(total_ious, axis=1))
  
  return pixel_acc, mean_iou

# %%
model.eval()
with torch.no_grad():
  pixel_acc, mean_iou = validation(model, validloader, criterion)

print("Pixel accuracy: ", pixel_acc, " Mean IoU: ", mean_iou)
# Out:
# Pixel accuracy:  0.009058581195477502  Mean IoU:  0.0021080404857117875

# %% [markdown]
# ### Train

# %%
train_losses=[]
train_losses_epoch=[]
valid_losses=[]
valid_losses_epoch=[]
meaniou_epoch=[]
for epoch in range(epochs):
  for i, batch in enumerate(trainloader):
    inputs_trn, labels_trn = batch['x'].to(device), batch['y'].to(device)
    
    model.train()
    optimizer.zero_grad()
    
    trn_outputs = model.forward(inputs_trn)
    trn_loss = criterion(trn_outputs, labels_trn)
    train_losses.append(trn_loss.item())
    trn_loss.backward()
    optimizer.step()
    if i % print_every == 0:
      print("Epoch: {}/{}.. ".format(epoch+1, epochs),
            "Training loss: {:.5f}.. ".format(trn_loss.item()))
  
  train_losses_epoch.append(mean(train_losses))
  train_losses=[]   
  
  model.eval()
  with torch.no_grad():
     paccuracy, meaniou = validation(model, validloader, criterion)
     for i, batch in enumerate(validloader):
       inputs_val, labels_val = batch['x'].to(device), batch['y'].to(device)
       val_outputs = model.forward(inputs_val)
       val_loss = criterion(val_outputs, labels_val)
       valid_losses.append(val_loss.item())
       
  valid_losses_epoch.append(mean(valid_losses))
  meaniou_epoch.append(meaniou)    
  print("Epoch: {}/{}.. ".format(epoch+1, epochs),
              "Validation loss: {:.5f}.. ".format(mean(valid_losses)),
              "Pixel accuracy.. {:.5f}".format(paccuracy),
              "Mean IU.. {:.5f}".format(meaniou))
  valid_losses=[] 


#Saving parameters
torch.save(model.state_dict(), "/content/drive/My Drive/fcn-model-modified_architecture1.1_65epoch_m0.5.pth")
pd.DataFrame(train_losses_epoch).to_csv("/content/drive/My Drive/trn_loss_modified_architecture1.1_65epoch_m0.5.csv",index=False)
pd.DataFrame(valid_losses_epoch).to_csv("/content/drive/My Drive/val_loss_modified_architecture1.1_65epoch_m0.5.csv",index=False)
pd.DataFrame(meaniou_epoch).to_csv("/content/drive/My Drive/meaniou_modified_architecture1.1_65epoch_m0.5.csv",index=False)
# Out:
# Epoch: 1/65..  Training loss: 0.73253..
# Epoch: 1/65..  Training loss: 0.66355..
# Epoch: 1/65..  Training loss: 0.65400..
# Epoch: 1/65..  Training loss: 0.64380..
# Epoch: 1/65..  Validation loss: 0.63001..  Pixel accuracy.. 0.74166 Mean IU.. 0.11033
# Epoch: 2/65..  Training loss: 0.63325..
# Epoch: 2/65..  Training loss: 0.62409..
# Epoch: 2/65..  Training loss: 0.61342..
# Epoch: 2/65..  Training loss: 0.60529..
# Epoch: 2/65..  Validation loss: 0.59023..  Pixel accuracy.. 0.79424 Mean IU.. 0.13748
# Epoch: 3/65..  Training loss: 0.59278..
# Epoch: 3/65..  Training loss: 0.58565..
# Epoch: 3/65..  Training loss: 0.56835..
# Epoch: 3/65..  Training loss: 0.55454..
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice
# Epoch: 3/65..  Validation loss: 0.55365..  Pixel accuracy.. 0.76710 Mean IU.. 0.14353
# Epoch: 4/65..  Training loss: 0.55199..
# Epoch: 4/65..  Training loss: 0.53963..
# Epoch: 4/65..  Training loss: 0.52801..
# Epoch: 4/65..  Training loss: 0.51068..
# Epoch: 4/65..  Validation loss: 0.50425..  Pixel accuracy.. 0.82146 Mean IU.. 0.16367
# Epoch: 5/65..  Training loss: 0.50345..
# Epoch: 5/65..  Training loss: 0.49536..
# Epoch: 5/65..  Training loss: 0.47910..
# Epoch: 5/65..  Training loss: 0.46282..
# Epoch: 5/65..  Validation loss: 0.45144..  Pixel accuracy.. 0.84518 Mean IU.. 0.17738
# Epoch: 6/65..  Training loss: 0.45899..
# Epoch: 6/65..  Training loss: 0.44290..
# Epoch: 6/65..  Training loss: 0.42885..
# Epoch: 6/65..  Training loss: 0.42563..
# Epoch: 6/65..  Validation loss: 0.40781..  Pixel accuracy.. 0.85140 Mean IU.. 0.18904
# Epoch: 7/65..  Training loss: 0.40725..
# Epoch: 7/65..  Training loss: 0.39833..
# Epoch: 7/65..  Training loss: 0.38338..
# Epoch: 7/65..  Training loss: 0.37361..
# Epoch: 7/65..  Validation loss: 0.36786..  Pixel accuracy.. 0.84340 Mean IU.. 0.17957
# Epoch: 8/65..  Training loss: 0.36225..
# Epoch: 8/65..  Training loss: 0.35571..
# Epoch: 8/65..  Training loss: 0.34124..
# Epoch: 8/65..  Training loss: 0.32764..
# Epoch: 8/65..  Validation loss: 0.31950..  Pixel accuracy.. 0.86406 Mean IU.. 0.19639
# Epoch: 9/65..  Training loss: 0.32109..
# Epoch: 9/65..  Training loss: 0.31077..
# Epoch: 9/65..  Training loss: 0.29970..
# Epoch: 9/65..  Training loss: 0.28306..
# Epoch: 9/65..  Validation loss: 0.28550..  Pixel accuracy.. 0.79170 Mean IU.. 0.17598
# Epoch: 10/65..  Training loss: 0.27962..
# Epoch: 10/65..  Training loss: 0.27108..
# Epoch: 10/65..  Training loss: 0.25867..
# Epoch: 10/65..  Training loss: 0.24691..
# Epoch: 10/65..  Validation loss: 0.24229..  Pixel accuracy.. 0.85592 Mean IU.. 0.19319
# Epoch: 11/65..  Training loss: 0.24094..
# Epoch: 11/65..  Training loss: 0.23361..
# Epoch: 11/65..  Training loss: 0.22351..
# Epoch: 11/65..  Training loss: 0.21538..
# Epoch: 11/65..  Validation loss: 0.21060..  Pixel accuracy.. 0.86478 Mean IU.. 0.20400
# Epoch: 12/65..  Training loss: 0.20702..
# Epoch: 12/65..  Training loss: 0.20049..
# Epoch: 12/65..  Training loss: 0.19312..
# Epoch: 12/65..  Training loss: 0.18536..
# Epoch: 12/65..  Validation loss: 0.18062..  Pixel accuracy.. 0.86124 Mean IU.. 0.20415
# Epoch: 13/65..  Training loss: 0.17709..
# Epoch: 13/65..  Training loss: 0.17247..
# Epoch: 13/65..  Training loss: 0.16259..
# Epoch: 13/65..  Training loss: 0.15627..
# Epoch: 13/65..  Validation loss: 0.15493..  Pixel accuracy.. 0.85768 Mean IU.. 0.19245
# Epoch: 14/65..  Training loss: 0.15445..
# Epoch: 14/65..  Training loss: 0.15080..
# Epoch: 14/65..  Training loss: 0.14343..
# Epoch: 14/65..  Training loss: 0.13270..
# Epoch: 14/65..  Validation loss: 0.13557..  Pixel accuracy.. 0.85924 Mean IU.. 0.21792
# Epoch: 15/65..  Training loss: 0.12912..
# Epoch: 15/65..  Training loss: 0.12733..
# Epoch: 15/65..  Training loss: 0.12203..
# Epoch: 15/65..  Training loss: 0.11469..
# Epoch: 15/65..  Validation loss: 0.12064..  Pixel accuracy.. 0.78689 Mean IU.. 0.17875
# Epoch: 16/65..  Training loss: 0.11140..
# Epoch: 16/65..  Training loss: 0.10363..
# Epoch: 16/65..  Training loss: 0.10015..
# Epoch: 16/65..  Training loss: 0.09711..
# Epoch: 16/65..  Validation loss: 0.10241..  Pixel accuracy.. 0.80297 Mean IU.. 0.18539
# Epoch: 17/65..  Training loss: 0.09263..
# Epoch: 17/65..  Training loss: 0.08922..
# Epoch: 17/65..  Training loss: 0.09023..
# Epoch: 17/65..  Training loss: 0.08369..
# Epoch: 17/65..  Validation loss: 0.08088..  Pixel accuracy.. 0.87826 Mean IU.. 0.23597
# Epoch: 18/65..  Training loss: 0.08035..
# Epoch: 18/65..  Training loss: 0.08428..
# Epoch: 18/65..  Training loss: 0.07186..
# Epoch: 18/65..  Training loss: 0.06987..
# Epoch: 18/65..  Validation loss: 0.06883..  Pixel accuracy.. 0.87987 Mean IU.. 0.24424
# Epoch: 19/65..  Training loss: 0.07291..
# Epoch: 19/65..  Training loss: 0.06423..
# Epoch: 19/65..  Training loss: 0.06508..
# Epoch: 19/65..  Training loss: 0.06445..
# Epoch: 19/65..  Validation loss: 0.08773..  Pixel accuracy.. 0.68177 Mean IU.. 0.15784
# Epoch: 20/65..  Training loss: 0.06397..
# Epoch: 20/65..  Training loss: 0.05901..
# Epoch: 20/65..  Training loss: 0.05267..
# Epoch: 20/65..  Training loss: 0.05167..
# Epoch: 20/65..  Validation loss: 0.05066..  Pixel accuracy.. 0.88770 Mean IU.. 0.25892
# Epoch: 21/65..  Training loss: 0.05211..
# Epoch: 21/65..  Training loss: 0.05535..
# Epoch: 21/65..  Training loss: 0.04247..
# Epoch: 21/65..  Training loss: 0.04443..
# Epoch: 21/65..  Validation loss: 0.04457..  Pixel accuracy.. 0.88363 Mean IU.. 0.25725
# Epoch: 22/65..  Training loss: 0.04362..
# Epoch: 22/65..  Training loss: 0.04521..
# Epoch: 22/65..  Training loss: 0.03933..
# Epoch: 22/65..  Training loss: 0.03749..
# Epoch: 22/65..  Validation loss: 0.04017..  Pixel accuracy.. 0.88406 Mean IU.. 0.25392
# Epoch: 23/65..  Training loss: 0.03891..
# Epoch: 23/65..  Training loss: 0.03787..
# Epoch: 23/65..  Training loss: 0.03604..
# Epoch: 23/65..  Training loss: 0.03445..
# Epoch: 23/65..  Validation loss: 0.03933..  Pixel accuracy.. 0.86277 Mean IU.. 0.25790
# Epoch: 24/65..  Training loss: 0.03937..
# Epoch: 24/65..  Training loss: 0.03251..
# Epoch: 24/65..  Training loss: 0.03533..
# Epoch: 24/65..  Training loss: 0.03056..
# Epoch: 24/65..  Validation loss: 0.03812..  Pixel accuracy.. 0.84765 Mean IU.. 0.24585
# Epoch: 25/65..  Training loss: 0.02995..
# Epoch: 25/65..  Training loss: 0.03697..
# Epoch: 25/65..  Training loss: 0.02818..
# Epoch: 25/65..  Training loss: 0.02824..
# Epoch: 25/65..  Validation loss: 0.03924..  Pixel accuracy.. 0.82547 Mean IU.. 0.24962
# Epoch: 26/65..  Training loss: 0.02600..
# Epoch: 26/65..  Training loss: 0.03246..
# Epoch: 26/65..  Training loss: 0.03227..
# Epoch: 26/65..  Training loss: 0.02287..
# Epoch: 26/65..  Validation loss: 0.02729..  Pixel accuracy.. 0.89247 Mean IU.. 0.28445
# Epoch: 27/65..  Training loss: 0.02708..
# Epoch: 27/65..  Training loss: 0.03168..
# Epoch: 27/65..  Training loss: 0.02700..
# Epoch: 27/65..  Training loss: 0.02353..
# Epoch: 27/65..  Validation loss: 0.02541..  Pixel accuracy.. 0.89550 Mean IU.. 0.29660
# Epoch: 28/65..  Training loss: 0.02215..
# Epoch: 28/65..  Training loss: 0.02025..
# Epoch: 28/65..  Training loss: 0.02544..
# Epoch: 28/65..  Training loss: 0.02491..
# Epoch: 28/65..  Validation loss: 0.02303..  Pixel accuracy.. 0.89737 Mean IU.. 0.28905
# Epoch: 29/65..  Training loss: 0.02091..
# Epoch: 29/65..  Training loss: 0.01657..
# Epoch: 29/65..  Training loss: 0.02243..
# Epoch: 29/65..  Training loss: 0.01962..
# Epoch: 29/65..  Validation loss: 0.02216..  Pixel accuracy.. 0.89868 Mean IU.. 0.30194
# Epoch: 30/65..  Training loss: 0.02286..
# Epoch: 30/65..  Training loss: 0.02173..
# Epoch: 30/65..  Training loss: 0.02103..
# Epoch: 30/65..  Training loss: 0.01895..
# Epoch: 30/65..  Validation loss: 0.03409..  Pixel accuracy.. 0.82787 Mean IU.. 0.23885
# Epoch: 31/65..  Training loss: 0.02172..
# Epoch: 31/65..  Training loss: 0.01753..
# Epoch: 31/65..  Training loss: 0.01771..
# Epoch: 31/65..  Training loss: 0.01573..
# Epoch: 31/65..  Validation loss: 0.02125..  Pixel accuracy.. 0.89568 Mean IU.. 0.31444
# Epoch: 32/65..  Training loss: 0.02158..
# Epoch: 32/65..  Training loss: 0.01977..
# Epoch: 32/65..  Training loss: 0.01768..
# Epoch: 32/65..  Training loss: 0.01908..
# Epoch: 32/65..  Validation loss: 0.02424..  Pixel accuracy.. 0.87777 Mean IU.. 0.27999
# Epoch: 33/65..  Training loss: 0.01721..
# Epoch: 33/65..  Training loss: 0.01816..
# Epoch: 33/65..  Training loss: 0.02444..
# Epoch: 33/65..  Training loss: 0.02087..
# Epoch: 33/65..  Validation loss: 0.01869..  Pixel accuracy.. 0.90492 Mean IU.. 0.32033
# Epoch: 34/65..  Training loss: 0.01637..
# Epoch: 34/65..  Training loss: 0.01548..
# Epoch: 34/65..  Training loss: 0.02043..
# Epoch: 34/65..  Training loss: 0.01836..
# Epoch: 34/65..  Validation loss: 0.01815..  Pixel accuracy.. 0.90705 Mean IU.. 0.32704
# Epoch: 35/65..  Training loss: 0.01552..
# Epoch: 35/65..  Training loss: 0.02271..
# Epoch: 35/65..  Training loss: 0.01524..
# Epoch: 35/65..  Training loss: 0.01508..
# Epoch: 35/65..  Validation loss: 0.02076..  Pixel accuracy.. 0.88975 Mean IU.. 0.30629
# Epoch: 36/65..  Training loss: 0.01654..
# Epoch: 36/65..  Training loss: 0.01365..
# Epoch: 36/65..  Training loss: 0.01733..
# Epoch: 36/65..  Training loss: 0.01396..
# Epoch: 36/65..  Validation loss: 0.01828..  Pixel accuracy.. 0.90216 Mean IU.. 0.32299
# Epoch: 37/65..  Training loss: 0.01830..
# Epoch: 37/65..  Training loss: 0.01430..
# Epoch: 37/65..  Training loss: 0.01493..
# Epoch: 37/65..  Training loss: 0.01389..
# Epoch: 37/65..  Validation loss: 0.02007..  Pixel accuracy.. 0.89346 Mean IU.. 0.30302
# Epoch: 38/65..  Training loss: 0.01690..
# Epoch: 38/65..  Training loss: 0.02200..
# Epoch: 38/65..  Training loss: 0.01643..
# Epoch: 38/65..  Training loss: 0.01328..
# Epoch: 38/65..  Validation loss: 0.02243..  Pixel accuracy.. 0.86829 Mean IU.. 0.29477
# Epoch: 39/65..  Training loss: 0.02063..
# Epoch: 39/65..  Training loss: 0.01773..
# Epoch: 39/65..  Training loss: 0.01844..
# Epoch: 39/65..  Training loss: 0.01518..
# Epoch: 39/65..  Validation loss: 0.01955..  Pixel accuracy.. 0.88775 Mean IU.. 0.31984
# Epoch: 40/65..  Training loss: 0.01805..
# Epoch: 40/65..  Training loss: 0.01360..
# Epoch: 40/65..  Training loss: 0.01992..
# Epoch: 40/65..  Training loss: 0.01257..
# Epoch: 40/65..  Validation loss: 0.01846..  Pixel accuracy.. 0.89550 Mean IU.. 0.32791
# Epoch: 41/65..  Training loss: 0.01014..
# Epoch: 41/65..  Training loss: 0.01240..
# Epoch: 41/65..  Training loss: 0.01416..
# Epoch: 41/65..  Training loss: 0.01148..
# Epoch: 41/65..  Validation loss: 0.01810..  Pixel accuracy.. 0.89926 Mean IU.. 0.30583
# Epoch: 42/65..  Training loss: 0.01916..
# Epoch: 42/65..  Training loss: 0.01522..
# Epoch: 42/65..  Training loss: 0.01490..
# Epoch: 42/65..  Training loss: 0.02027..
# Epoch: 42/65..  Validation loss: 0.01769..  Pixel accuracy.. 0.90067 Mean IU.. 0.33704
# Epoch: 43/65..  Training loss: 0.01235..
# Epoch: 43/65..  Training loss: 0.01319..
# Epoch: 43/65..  Training loss: 0.01107..
# Epoch: 43/65..  Training loss: 0.01269..
# Epoch: 43/65..  Validation loss: 0.02205..  Pixel accuracy.. 0.87481 Mean IU.. 0.30463
# Epoch: 44/65..  Training loss: 0.01638..
# Epoch: 44/65..  Training loss: 0.02433..
# Epoch: 44/65..  Training loss: 0.01230..
# Epoch: 44/65..  Training loss: 0.01790..
# Epoch: 44/65..  Validation loss: 0.01663..  Pixel accuracy.. 0.90752 Mean IU.. 0.33629
# Epoch: 45/65..  Training loss: 0.01655..
# Epoch: 45/65..  Training loss: 0.01371..
# Epoch: 45/65..  Training loss: 0.01584..
# Epoch: 45/65..  Training loss: 0.02639..
# Epoch: 45/65..  Validation loss: 0.02216..  Pixel accuracy.. 0.87945 Mean IU.. 0.30860
# Epoch: 46/65..  Training loss: 0.01433..
# Epoch: 46/65..  Training loss: 0.01364..
# Epoch: 46/65..  Training loss: 0.01130..
# Epoch: 46/65..  Training loss: 0.01141..
# Epoch: 46/65..  Validation loss: 0.01636..  Pixel accuracy.. 0.90725 Mean IU.. 0.33659
# Epoch: 47/65..  Training loss: 0.00985..
# Epoch: 47/65..  Training loss: 0.01362..
# Epoch: 47/65..  Training loss: 0.01104..
# Epoch: 47/65..  Training loss: 0.01847..
# Epoch: 47/65..  Validation loss: 0.01692..  Pixel accuracy.. 0.90547 Mean IU.. 0.34029
# Epoch: 48/65..  Training loss: 0.01229..
# Epoch: 48/65..  Training loss: 0.01329..
# Epoch: 48/65..  Training loss: 0.01476..
# Epoch: 48/65..  Training loss: 0.01048..
# Epoch: 48/65..  Validation loss: 0.01669..  Pixel accuracy.. 0.90852 Mean IU.. 0.33842
# Epoch: 49/65..  Training loss: 0.02206..
# Epoch: 49/65..  Training loss: 0.01075..
# Epoch: 49/65..  Training loss: 0.01633..
# Epoch: 49/65..  Training loss: 0.01144..
# Epoch: 49/65..  Validation loss: 0.01797..  Pixel accuracy.. 0.89576 Mean IU.. 0.33250
# Epoch: 50/65..  Training loss: 0.01174..
# Epoch: 50/65..  Training loss: 0.01180..
# Epoch: 50/65..  Training loss: 0.00910..
# Epoch: 50/65..  Training loss: 0.01125..
# Epoch: 50/65..  Validation loss: 0.01588..  Pixel accuracy.. 0.91004 Mean IU.. 0.34598
# Epoch: 51/65..  Training loss: 0.01012..
# Epoch: 51/65..  Training loss: 0.00953..
# Epoch: 51/65..  Training loss: 0.01080..
# Epoch: 51/65..  Training loss: 0.01276..
# Epoch: 51/65..  Validation loss: 0.01584..  Pixel accuracy.. 0.91160 Mean IU.. 0.35396
# Epoch: 52/65..  Training loss: 0.01482..
# Epoch: 52/65..  Training loss: 0.01450..
# Epoch: 52/65..  Training loss: 0.01678..
# Epoch: 52/65..  Training loss: 0.01342..
# Epoch: 52/65..  Validation loss: 0.01600..  Pixel accuracy.. 0.90866 Mean IU.. 0.33942
# Epoch: 53/65..  Training loss: 0.01401..
# Epoch: 53/65..  Training loss: 0.01224..
# Epoch: 53/65..  Training loss: 0.01094..
# Epoch: 53/65..  Training loss: 0.01488..
# Epoch: 53/65..  Validation loss: 0.04719..  Pixel accuracy.. 0.72835 Mean IU.. 0.24975
# Epoch: 54/65..  Training loss: 0.02008..
# Epoch: 54/65..  Training loss: 0.01001..
# Epoch: 54/65..  Training loss: 0.01076..
# Epoch: 54/65..  Training loss: 0.01236..
# Epoch: 54/65..  Validation loss: 0.01531..  Pixel accuracy.. 0.91285 Mean IU.. 0.35937
# Epoch: 55/65..  Training loss: 0.00989..
# Epoch: 55/65..  Training loss: 0.01172..
# Epoch: 55/65..  Training loss: 0.01039..
# Epoch: 55/65..  Training loss: 0.01843..
# Epoch: 55/65..  Validation loss: 0.01825..  Pixel accuracy.. 0.90079 Mean IU.. 0.32950
# Epoch: 56/65..  Training loss: 0.01266..
# Epoch: 56/65..  Training loss: 0.01633..
# Epoch: 56/65..  Training loss: 0.00997..
# Epoch: 56/65..  Training loss: 0.01655..
# Epoch: 56/65..  Validation loss: 0.01523..  Pixel accuracy.. 0.91609 Mean IU.. 0.35869
# Epoch: 57/65..  Training loss: 0.01116..
# Epoch: 57/65..  Training loss: 0.00951..
# Epoch: 57/65..  Training loss: 0.01051..
# Epoch: 57/65..  Training loss: 0.01180..
# Epoch: 57/65..  Validation loss: 0.01632..  Pixel accuracy.. 0.90491 Mean IU.. 0.35722
# Epoch: 58/65..  Training loss: 0.00926..
# Epoch: 58/65..  Training loss: 0.01346..
# Epoch: 58/65..  Training loss: 0.00980..
# Epoch: 58/65..  Training loss: 0.00936..
# Epoch: 58/65..  Validation loss: 0.01541..  Pixel accuracy.. 0.91471 Mean IU.. 0.36687
# Epoch: 59/65..  Training loss: 0.01065..
# Epoch: 59/65..  Training loss: 0.01524..
# Epoch: 59/65..  Training loss: 0.01288..
# Epoch: 59/65..  Training loss: 0.01729..
# Epoch: 59/65..  Validation loss: 0.01652..  Pixel accuracy.. 0.90896 Mean IU.. 0.35565
# Epoch: 60/65..  Training loss: 0.01350..
# Epoch: 60/65..  Training loss: 0.01552..
# Epoch: 60/65..  Training loss: 0.00885..
# Epoch: 60/65..  Training loss: 0.00877..
# Epoch: 60/65..  Validation loss: 0.01722..  Pixel accuracy.. 0.90473 Mean IU.. 0.36338
# Epoch: 61/65..  Training loss: 0.00977..
# Epoch: 61/65..  Training loss: 0.01129..
# Epoch: 61/65..  Training loss: 0.00990..
# Epoch: 61/65..  Training loss: 0.01154..
# Epoch: 61/65..  Validation loss: 0.01564..  Pixel accuracy.. 0.91164 Mean IU.. 0.37393
# Epoch: 62/65..  Training loss: 0.01147..
# Epoch: 62/65..  Training loss: 0.01035..
# Epoch: 62/65..  Training loss: 0.01267..
# Epoch: 62/65..  Training loss: 0.01218..
# Epoch: 62/65..  Validation loss: 0.01649..  Pixel accuracy.. 0.90513 Mean IU.. 0.36993
# Epoch: 63/65..  Training loss: 0.01629..
# Epoch: 63/65..  Training loss: 0.01076..
# Epoch: 63/65..  Training loss: 0.01571..
# Epoch: 63/65..  Training loss: 0.01232..
# Epoch: 63/65..  Validation loss: 0.01591..  Pixel accuracy.. 0.91458 Mean IU.. 0.37268
# Epoch: 64/65..  Training loss: 0.00811..
# Epoch: 64/65..  Training loss: 0.00979..
# Epoch: 64/65..  Training loss: 0.01023..
# Epoch: 64/65..  Training loss: 0.01145..
# Epoch: 64/65..  Validation loss: 0.02365..  Pixel accuracy.. 0.87820 Mean IU.. 0.30013
# Epoch: 65/65..  Training loss: 0.01914..
# Epoch: 65/65..  Training loss: 0.00967..
# Epoch: 65/65..  Training loss: 0.01033..
# Epoch: 65/65..  Training loss: 0.01174..
# Epoch: 65/65..  Validation loss: 0.01537..  Pixel accuracy.. 0.91421 Mean IU.. 0.37566

# %% [markdown]
# ### Check accuracy after training

# %%
model.eval()
with torch.no_grad():
  pixel_acc, mean_iou = validation(model, validloader, criterion)

print("Pixel accuracy: ", pixel_acc, " Mean IoU: ", mean_iou)
# Out:
# Pixel accuracy:  0.8929748180192072  Mean IoU:  0.2560160674717217
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice

# %% [markdown]
# ### Visualization

# %%
#Training Loss
pd.read_csv("/content/drive/My Drive/trn_loss_modified_architecture1.1_65epoch_m0.5.csv")

# %%
#Validation Loss
pd.read_csv("/content/drive/My Drive/val_loss_modified_architecture1.1_65epoch_m0.5.csv")

# %%
#Mean IOU
pd.read_csv("/content/drive/My Drive/meaniou_modified_architecture1.1_65epoch_m0.5.csv")

# %% [markdown]
# Training Loss PLot

# %%
plt.plot(train_losses_epoch, label='Training loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Make inference

# %%
n_classes = 32
model = FCN8s(VGG16(cfg, ranges), n_classes)
state_dict = torch.load("/content/drive/My Drive/fcn-model-modified_architecture1.1_65epoch_m0.5.pth")
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
model.to(device)
model.eval()
with torch.no_grad():
  pixel_acc, mean_iou = validation(model, validloader, criterion)

print("Pixel accuracy: ", pixel_acc, " Mean IoU: ", mean_iou)
# Out:
# Pixel accuracy:  0.9081846967544768  Mean IoU:  0.33396785468570844
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice

# %%
def plot_imgs(images = [], titles = [], figsize = (10,10)):
  size = len(images)
  fig = plt.figure(figsize=figsize)
  i = 1
  for image in images:
    ax = fig.add_subplot(1,size,i)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(titles[i-1])
    ax.imshow(image)
    i += 1
  return None
  
#Id : [Label, (RGB code)]
gt_labels = {1 : ["Animal", (64, 128, 64)],
            2 : ["Archway", (192, 0, 128)],
            3 : ["Bicyclist", (0, 128, 192)],
            4 : ["Bridge", (0, 128, 64)],
            5 : ["Building", (128, 0, 0,)],
            6 : ["Car", (64, 0, 128)],
            7 : ["CartLuggagePram", (64, 0, 192)],
            8 : ["Child", (192, 128, 64)],
            9 : ["Column_Pole", (192, 192, 128)],
            10: ["Fence", (64, 64, 128)],
            11: ["LaneMkgsDriv", (128, 0, 192)],
            12: ["LaneMkgsNonDriv", (192, 0, 64)],
            13: ["Misc_Text", (128, 128, 64)],
            14: ["MotorcycleScooter", (192, 0, 192)],
            15: ["OtherMoving", (128, 64, 64)],
            16: ["ParkingBlock", (64, 192, 128)],
            17: ["Pedestrian", (64, 64, 0)],
            18: ["Road", (128, 64, 128)],
            19: ["RoadShoulder", (128, 128, 192)],
            20: ["Sidewalk", (0, 0, 192)],
            21: ["SignSymbol", (192, 128, 128)],
            22: ["Sky", (128, 128, 128)],
            23: ["SUVPickupTruck", (64, 128, 192)],
            24: ["TrafficCone", (0, 0, 64)],
            25: ["TrafficLight", (0, 64, 64)],
            26: ["Train", (192, 64, 128)],
            27: ["Tree", (128, 128, 0)],
            28: ["Truck_Bus", (192, 128, 192)],
            29: ["Tunnel", (64, 0, 64)],
            30: ["VegetationMisc", (192, 192, 0)],
            31: ["Void", (0, 0, 0)],
            32: ["Wall", (64, 192, 0)]}

# %%
from PIL import Image
import warnings

warnings.filterwarnings("ignore")

inference_transforms = transforms.Compose([ transforms.Resize((704,960)),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.460],[0.229, 0.224, 0.225])])
def load_image(image):
  if isinstance(image, str):
    image = Image.open(image).convert('RGB')
  else:
    image = Image.fromarray(image).convert('RGB')
  image = inference_transforms(image)
  image = torch.tensor(image, requires_grad=False)
  image = image.unsqueeze(0)
  return image

def get_predicted_image(original, prediction, labels=None):
  _, h, w = prediction.shape
  _, oh, ow = original.shape
  if h != oh or w != ow:
    original =np.array(Image.fromarray(original).resize(size=(704, 960))) #scipy.misc.imresize(original, (704, 960))
  output = np.zeros((h, w, 3), dtype=np.uint8)
  for i in range(h):
    for j in range(w):
      index = prediction[0][i][j] + 1
      try:
        if labels is not None:
          if index in labels:
            color = gt_labels.get(index)[1]
            output[i, j, 0] = color[0]
            output[i, j, 1] = color[1]
            output[i, j, 2] = color[2]
          else:
            output[i, j, 0] = original[i, j, 0]
            output[i, j, 1] = original[i, j, 1]
            output[i, j, 2] = original[i, j, 2]
        else:
          color = gt_labels.get(index)[1]
          output[i, j, 0] = color[0]
          output[i, j, 1] = color[1]
          output[i, j, 2] = color[2]
      except:
        print("Upss, didn't work")
        break
  return output

def get_image_labels(testimage):
  model.to(device)
  model.eval()
  image = load_image(testimage)
  prediction = model(image.to(device))
  prediction = prediction.data.cpu().numpy()
  N, _, h, w = prediction.shape
  prediction = prediction.transpose(0, 2, 3, 1).reshape(-1, 32).argmax(axis=1).reshape(N, h, w)
  return prediction

# %% [markdown]
# ### Compare prediction with ground truth

# %%
name = "Seq05VD_f04050"

inp_image = "/content/drive/My Drive/CamVid/train/" + name + ".png"
tru_image = "/content/drive/My Drive/CamVid/train_labels/" + name + "_L.png"

original = imageio.imread(inp_image)
truth = imageio.imread(tru_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))

plot_imgs([original, truth, predicted], ["Original", "Ground truth", "Prediction"], (45,45))

# %%
name = ["0006R0_f01920","0006R0_f02790","0016E5_06330","0016E5_07800"]
for nam in name:
  inp_image = "/content/drive/My Drive/CamVid/val/" + nam + ".png"
  #tru_image = "/content/drive/My Drive/CamVid/val_labels/" + nam + "_L.png"

  prd=get_predicted_image(imageio.imread(inp_image), get_image_labels(inp_image))
  plot_imgs([prd], ["Prediction"], (15, 15))

# %%
name = ["0006R0_f01920","0006R0_f02790","0016E5_06330","0016E5_07800"]
for nam in name:
  inp_image = "/content/drive/My Drive/CamVid/val/" + nam + ".png"
  tru_image = "/content/drive/My Drive/CamVid/val_labels/" + nam + "_L.png"

  original = imageio.imread(inp_image)
  truth = imageio.imread(tru_image)
  predicted = get_predicted_image(original, get_image_labels(inp_image))

  plot_imgs([original, truth, predicted], ["Original", "Ground truth", "Prediction"], (100, 100))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Predict on an unlabeled image

# %%
name = ["/content/drive/My Drive/CamVid/City_Road_Cardiff.jpg",
        "/content/drive/My Drive/CamVid/City-Road-in-Cardiff2.jpg",
        "/content/drive/My Drive/CamVid/Road US.jpg"]
for inp_image in name:

  prd=get_predicted_image(imageio.imread(inp_image), get_image_labels(inp_image))
  plot_imgs([prd], ["Prediction"], (15, 15))

# %%
inp_image = "/content/drive/My Drive/CamVid/City_Road_Cardiff.jpg"

original = imageio.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %%
inp_image = "/content/drive/My Drive/CamVid/City-Road-in-Cardiff2.jpg"

original = imageio.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %%
inp_image = "/content/drive/My Drive/CamVid/Road US.jpg"

original = imageio.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image))
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %% [markdown]
# ### Segment a selected group of labels

# %%
name = "Seq05VD_f01800"

inp_image = "data/CamVid/701_StillsRaw_full/" + name + ".png"
tru_image = "data/CamVid/LabeledApproved_full/" + name + "_L.png"

original = scipy.misc.imread(inp_image)
truth = scipy.misc.imread(tru_image)
predicted = get_predicted_image(original, get_image_labels(inp_image), [11, 12, 18, 19]) # Only road labels

plot_imgs([original, truth, predicted], ["Original", "Ground truth", "Prediction"], (15, 15))

# %%
inp_image = "data/testimage2.png"

original = scipy.misc.imread(inp_image)
predicted = get_predicted_image(original, get_image_labels(inp_image), [11, 12, 18, 19]) # Only road labels
   
plot_imgs([original, predicted], ["Original", "Prediction"], (15, 15))

# %% [markdown]
# ### Inference on video

# %%
import glob
import os 
import cv2

def get_frame_rate(video):
    video = cv2.VideoCapture(video);
    # Find OpenCV version
    (major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
    if int(major_ver)  < 3 :
        fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
        print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(int(fps)))
    else :
        fps = video.get(cv2.CAP_PROP_FPS)
        print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(int(fps)))
    video.release();
    return int(fps)
    
def process_video(video, path_to_save):
    cap = cv2.VideoCapture(video)
    print("Number of frames: ", int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
    ret, frame = cap.read()
    cont = 0
    while ret:
        if cont > 17100 and cont < 17710:
          #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
          prediction = get_predicted_image(frame, get_image_labels(frame), [11, 12, 18, 19]) # Only road labels
          cv2.imwrite(path_to_save + str(cont) + ".png", prediction)
        cont += 1
        ret, frame = cap.read()
    print("Video processed.")

def make_video(outvid, images=None, fps=30, size=None, is_color=True, format="FMP4"):
    fourcc = cv2.VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = cv2.imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = cv2.VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = cv2.resize(img, size)
        vid.write(img)
    vid.release()
    return vid
    
def detect_on_video(video, out_path, fps):
    # Process video to get all the frames with detections
    process_video(video, out_path)
    # Get processed frames and order by name
    images = list(glob.iglob(os.path.join(out_path, '*.png')))
    images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))
    # Create the video from processed frames
    make_video(out_path+"output.mp4", images, fps)
    print("Video: "+ out_path +" output.mp4 it's ready")

video = './../YOLO/images/timelapse.mp4'
path = './data/processed/'

fps = get_frame_rate(video)
detect_on_video(video, path, fps+1)
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 29
# Number of frames:  22339
# Video processed.
# Video: ./data/processed/ output.mp4 it's ready

# %% [markdown]
# ### Video output (converted as GIF)

# %% [markdown]
# ![Video-output](/images/outputgif.gif)
